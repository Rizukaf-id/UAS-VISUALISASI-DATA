# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup
import pandas as pd
import cloudscraper
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver import Chrome
from selenium.webdriver.chrome.options import Options
import os
from selenium.webdriver.common.by import By
from datetime import datetime
import requests

# %%
path = "chromedriver-win64/chromedriver-win64/chromedriver.exe"

chrome_options = Options()
chrome_options.add_argument("--headless")
service = Service(path)

browser = Chrome(options=chrome_options, service = service)

browser.get('https://www.google.com')
search_box = browser.find_element('id','APjFqb')

search_box.clear()
search_box.send_keys("anime")
search_box.submit()


page = browser.page_source
soup = BeautifulSoup(page,'html.parser') 

rows = soup.findAll("div", {"class":"N54PNb BToiNc cvP2Ce"})
print(len(rows))
for row in rows:

    link = row.find("a").get('href')
    title = row.find("h3", {"class":"LC20lb MBeuO DKV0Md"}).text
    texts = row.find("span",{"class":""}).text
    print(link)
    print(title)
    print(texts)
    print("")
# Out:
# 9
# https://www.vidio.com/categories/anime
# Nonton Anime Terbaru 2024 Sub Indo
# Nonton Anime Terbaru 2024 Sub IndoVidiohttps://www.vidio.com › categories › anime
#
# https://www.viu.com/ott/id/id/category/574/Anime
# Nonton Anime Terbaru | Sub Indo
# Nonton Anime Terbaru | Sub IndoViuhttps://www.viu.com › ott › category › Anime
#
# https://id.wikipedia.org/wiki/Anime
# Anime - Wikipedia bahasa Indonesia, ensiklopedia bebas
# Anime - Wikipedia bahasa Indonesia, ensiklopedia bebasWikipediahttps://id.wikipedia.org › wiki › Anime
#
# https://id.pinterest.com/cstlla_/anime/
# 900+ ide Anime di 2024 | animasi, gambar, ilustrasi karakter
# 900+ ide Anime di 2024 | animasi, gambar, ilustrasi karakterPinteresthttps://id.pinterest.com › cstlla_ › anime
#
# https://www.netflix.com/browse/genre/6721
# Anime Series | Netflix Official Site
# Anime Series | Netflix Official SiteNetflixhttps://www.netflix.com › ge...
#
# https://www.iq.com/anime?lang=id_id
# Anime & Kartun Asia | Nonton online Gratis dengan sub ...
# Anime & Kartun Asia | Nonton online Gratis dengan sub ...iQIYIhttps://www.iq.com › iQiyi › iQiyi
#
# https://www.anime-expo.org/
# Anime Expo | Los Angeles Anime Convention
# Anime Expo | Los Angeles Anime ConventionAnime Expohttps://www.anime-expo.org
#
# https://en.wikipedia.org/wiki/Anime
# Anime
# AnimeWikipediahttps://en.wikipedia.org › A...
#
# https://animefestival.asia/
# Anime Festival Asia - JAPAN POP CULTURE NOW!
# Anime Festival Asia - JAPAN POP CULTURE NOW!Anime Festival Asiahttps://animefestival.asia

# %%
url = 'https://www.imdb.com/chart/top/?ref_=nv_mv_250'
scraper = cloudscraper.create_scraper(delay=10, browser="chrome") 
content = scraper.get(url).text

# %%
chrome_options = Options()
# chrome_options.add_argument("--headless")
service = Service(path)

browser = Chrome(options=chrome_options, service = service)

browser.get(url)
content = browser.page_source
soup = BeautifulSoup(content,'html.parser')
print(soup.prettify())
movies = soup.findAll("div", {"class": "sc-b189961a-0 hBZnfJ cli-children"})
print(len(movies))
# Out:
# <html class="scriptsOn" lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <script async="" crossorigin="anonymous" src="https://images-na.ssl-images-amazon.com/images/I/31bJewCvY-L.js">
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <script>
#    if(typeof uet === 'function'){ uet('bb', 'LoadTitle', {wb: 1}); }
#   </script>
#   <title>
#    IMDb Top 250 Movies
#   </title>
#   <meta content="As rated by regular IMDb voters." data-id="main" name="description"/>
#   <meta content="IMDb" property="og:site_name"/>
#   <meta content="IMDb Top 250 Movies" property="og:title"/>
#   <meta content="As rated by regular IMDb voters." property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://m.media-amazon.com/images/G/01/imdb/images/social/imdb_logo.png" property="og:image"/>
#   <meta content="1000" property="og:image:height"/>
#   <meta content="1000" property="og:image:width"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="@IMDb" property="twitter:site"/>
#   <meta content="IMDb Top 250 Movies" property="twitter:title"/>
#   <meta content="As rated by regular IMDb voters." property="twitter:description"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="https://m.media-amazon.com/images/G/01/imdb/images/social/imdb_logo.png" property="twitter:image"/>
#   <meta content="As rated by regular IMDb voters." property="twitter:image:alt"/>
#   <meta content="chart" property="imdb:pageType"/>
#   <meta content="top250movie" property="imdb:subPageType"/>
#   <script>
#    if(typeof uet === 'function'){ uet('be', 'LoadTitle', {wb: 1}); }
#   </script>
#   <script>
#    if(typeof uex === 'function'){ uex('ld', 'LoadTitle', {wb: 1}); }
#   </script>
#   <meta charset="utf-8"/>
#   <script>
#    window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadTitle',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyBegin', 1718099841758);
#         }
#     })
#   </script>
#   <script>
#    window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadTitle',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyEnd', 1718099841758);
#         }
#     })
#   </script>
#   <script>
#    window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadTitle',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToLoaded', 1718099841758);
#         }
#     })
#   </script>
#   <meta content="26" name="next-head-count"/>
#   <script>
#    var ue_t0=ue_t0||+new Date();
#
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# (function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){try{return b.apply(this,arguments)}catch(c){ueLogError(c,{attribution:a||"undefined",logLevel:"WARN"})}}}})(ue_csm);
#
#
#     var ue_err_chan = 'jserr';
# (function(d,e){function h(f,b){if(!(a.ec>a.mxe)&&f){a.ter.push(f);b=b||{};var c=f.logLevel||b.logLevel;c&&c!==k&&c!==m&&c!==n&&c!==p||a.ec++;c&&c!=k||a.ecf++;b.pageURL=""+(e.location?e.location.href:"");b.logLevel=c;b.attribution=f.attribution||b.attribution;a.erl.push({ex:f,info:b})}}function l(a,b,c,e,g){d.ueLogError({m:a,f:b,l:c,c:""+e,err:g,fromOnError:1,args:arguments},g?{attribution:g.attribution,logLevel:g.logLevel}:void 0);return!1}var k="FATAL",m="ERROR",n="WARN",p="DOWNGRADED",a={ec:0,ecf:0,
# pec:0,ts:0,erl:[],ter:[],buffer:[],mxe:50,startTimer:function(){a.ts++;setInterval(function(){d.ue&&a.pec<a.ec&&d.uex("at");a.pec=a.ec},1E4)}};l.skipTrace=1;h.skipTrace=1;h.isStub=1;d.ueLogError=h;d.ue_err=a;e.onerror=l})(ue_csm,window);
#
#
# var ue_id = 'RGRS4XPFBK3JY7C1RV7P',
#     ue_url,
#     ue_navtiming = 1,
#     ue_mid = 'A1EVAM02EL8SFB',
#     ue_sid = '137-3713988-0011656',
#     ue_sn = 'www.imdb.com',
#     ue_furl = 'fls-na.amazon.com',
#     ue_surl = 'https://unagi-na.amazon.com/1/events/com.amazon.csm.nexusclient.prod',
#     ue_int = 0,
#     ue_fcsn = 1,
#     ue_urt = 3,
#     ue_rpl_ns = 'cel-rpl',
#     ue_ddq = 1,
#     ue_fpf = '//fls-na.amazon.com/1/batch/1/OP/A1EVAM02EL8SFB:137-3713988-0011656:RGRS4XPFBK3JY7C1RV7P$uedata=s:',
#     ue_sbuimp = 1,
#     ue_ibft = 0,
#     ue_sswmts = 0,
#     ue_jsmtf = 0,
#     ue_fnt = 0,
#     ue_lpsi = 6000,
#     ue_no_counters = 0,
#     ue_lob = '6',
#     ue_sjslob = 0,
#
#     ue_swi = 1;
# var ue_viz=function(){(function(b,f,d){function g(){return(!(p in d)||0<d[p])&&(!(q in d)||0<d[q])}function h(c){if(b.ue.viz.length<w&&!r){var a=c.type;c=c.originalEvent;/^focus./.test(a)&&c&&(c.toElement||c.fromElement||c.relatedTarget)||(a=g()?f[s]||("blur"==a||"focusout"==a?t:u):t,b.ue.viz.push(a+":"+(+new Date-b.ue.t0)),a==u&&(b.ue.isl&&x("at"),r=1))}}for(var r=0,x=b.uex,a,k,l,s,v=["","webkit","o","ms","moz"],e=0,m=1,u="visible",t="hidden",p="innerWidth",q="innerHeight",w=20,n=0;n<v.length&&!e;n++)if(a=
# v[n],k=(a?a+"H":"h")+"idden",e="boolean"==typeof f[k])l=a+"visibilitychange",s=(a?a+"V":"v")+"isibilityState";h({});e&&f.addEventListener(l,h,0);m=g()?1:0;d.addEventListener("resize",function(){var a=g()?1:0;m!==a&&(m=a,h({}))},{passive:!0});b.ue&&e&&(b.ue.pageViz={event:l,propHid:k})})(ue_csm,ue_csm.document,ue_csm.window)};
#
# (function(d,h,N){function H(a){return a&&a.replace&&a.replace(/^\s+|\s+$/g,"")}function u(a){return"undefined"===typeof a}function B(a,b){for(var c in b)b[v](c)&&(a[c]=b[c])}function I(a){try{var b=N.cookie.match(RegExp("(^| )"+a+"=([^;]+)"));if(b)return b[2].trim()}catch(c){}}function O(k,b,c){var q=(x||{}).type;if("device"!==c||2!==q&&1!==q)k&&(d.ue_id=a.id=a.rid=k,w&&(w=w.replace(/((.*?:){2})(\w+)/,function(a,b){return b+k})),D&&(e("id",D,k),D=0)),b&&(w&&(w=w.replace(/(.*?:)(\w|-)+/,function(a,
# c){return c+b})),d.ue_sid=b),c&&a.tag("page-source:"+c),d.ue_fpf=w}function P(){var a={};return function(b){b&&(a[b]=1);b=[];for(var c in a)a[v](c)&&b.push(c);return b}}function y(d,b,c,q){q=q||+new E;var g,m;if(b||u(c)){if(d)for(m in g=b?e("t",b)||e("t",b,{}):a.t,g[d]=q,c)c[v](m)&&e(m,b,c[m]);return q}}function e(d,b,c){var e=b&&b!=a.id?a.sc[b]:a;e||(e=a.sc[b]={});"id"===d&&c&&(Q=1);return e[d]=c||e[d]}function R(d,b,c,e,g){c="on"+c;var m=b[c];"function"===typeof m?d&&(a.h[d]=m):m=function(){};b[c]=
# function(a){g?(e(a),m(a)):(m(a),e(a))};b[c]&&(b[c].isUeh=1)}function S(k,b,c,q){function p(b,c){var d=[b],f=0,g={},m,h;c?(d.push("m=1"),g[c]=1):g=a.sc;for(h in g)if(g[v](h)){var q=e("wb",h),p=e("t",h)||{},n=e("t0",h)||a.t0,l;if(c||2==q){q=q?f++:"";d.push("sc"+q+"="+h);for(l in p)u(p[l])||null===p[l]||d.push(l+q+"="+(p[l]-n));d.push("t"+q+"="+p[k]);if(e("ctb",h)||e("wb",h))m=1}}!J&&m&&d.push("ctb=1");return d.join("&")}function m(b,c,f,e,g){if(b){var k=d.ue_err;d.ue_url&&!e&&!g&&b&&0<b.length&&(e=
# new Image,a.iel.push(e),e.src=b,a.count&&a.count("postbackImageSize",b.length));w?(g=h.encodeURIComponent)&&b&&(e=new Image,b=""+d.ue_fpf+g(b)+":"+(+new E-d.ue_t0),a.iel.push(e),e.src=b):a.log&&(a.log(b,"uedata",{n:1}),a.ielf.push(b));k&&!k.ts&&k.startTimer();a.b&&(k=a.b,a.b="",m(k,c,f,1))}}function A(b){var c=x?x.type:F,d=2==c||a.isBFonMshop,c=c&&!d,f=a.bfini;if(!Q||a.isBFCache)f&&1<f&&(b+="&bfform=1",c||(a.isBFT=f-1)),d&&(b+="&bfnt=1",a.isBFT=a.isBFT||1),a.ssw&&a.isBFT&&(a.isBFonMshop&&(a.isNRBF=
# 0),u(a.isNRBF)&&(d=a.ssw(a.oid),d.e||u(d.val)||(a.isNRBF=1<d.val?0:1)),u(a.isNRBF)||(b+="&nrbf="+a.isNRBF)),a.isBFT&&!a.isNRBF&&(b+="&bft="+a.isBFT);return b}if(!a.paused&&(b||u(c))){for(var l in c)c[v](l)&&e(l,b,c[l]);a.isBFonMshop||y("pc",b,c);l="ld"===k&&b&&e("wb",b);var s=e("id",b)||a.id;l||s===a.oid||(D=b,ba(s,(e("t",b)||{}).tc||+e("t0",b),+e("t0",b)));var s=e("id",b)||a.id,t=e("id2",b),f=a.url+"?"+k+"&v="+a.v+"&id="+s,J=e("ctb",b)||e("wb",b),z;J&&(f+="&ctb="+J);t&&(f+="&id2="+t);1<d.ueinit&&
# (f+="&ic="+d.ueinit);if(!("ld"!=k&&"ul"!=k||b&&b!=s)){if("ld"==k){try{h[K]&&h[K].isUeh&&(h[K]=null)}catch(I){}if(h.chrome)for(t=0;t<L.length;t++)T(G,L[t]);(t=N.ue_backdetect)&&t.ue_back&&t.ue_back.value++;d._uess&&(z=d._uess());a.isl=1}a._bf&&(f+="&bf="+a._bf());d.ue_navtiming&&g&&(e("ctb",s,"1"),a.isBFonMshop||y("tc",F,F,M));!C||a.isBFonMshop||U||(g&&B(a.t,{na_:g.navigationStart,ul_:g.unloadEventStart,_ul:g.unloadEventEnd,rd_:g.redirectStart,_rd:g.redirectEnd,fe_:g.fetchStart,lk_:g.domainLookupStart,
# _lk:g.domainLookupEnd,co_:g.connectStart,_co:g.connectEnd,sc_:g.secureConnectionStart,rq_:g.requestStart,rs_:g.responseStart,_rs:g.responseEnd,dl_:g.domLoading,di_:g.domInteractive,de_:g.domContentLoadedEventStart,_de:g.domContentLoadedEventEnd,_dc:g.domComplete,ld_:g.loadEventStart,_ld:g.loadEventEnd,ntd:("function"!==typeof C.now||u(M)?0:new E(M+C.now())-new E)+a.t0}),x&&B(a.t,{ty:x.type+a.t0,rc:x.redirectCount+a.t0}),U=1);a.isBFonMshop||B(a.t,{hob:d.ue_hob,hoe:d.ue_hoe});a.ifr&&(f+="&ifr=1")}y(k,
# b,c,q);var r,n;l||b&&b!==s||ca(b);(c=d.ue_mbl)&&c.cnt&&!l&&(f+=c.cnt());l?e("wb",b,2):"ld"==k&&(a.lid=H(s));for(r in a.sc)if(1==e("wb",r))break;if(l){if(a.s)return;f=p(f,null)}else c=p(f,null),c!=f&&(c=A(c),a.b=c),z&&(f+=z),f=p(f,b||a.id);f=A(f);if(a.b||l)for(r in a.sc)2==e("wb",r)&&delete a.sc[r];z=0;a._rt&&(f+="&rt="+a._rt());c=h.csa;if(!l&&c)for(n in r=e("t",b)||{},c=c("PageTiming"),r)r[v](n)&&c("mark",da[n]||n,r[n]);l||(a.s=0,(n=d.ue_err)&&0<n.ec&&n.pec<n.ec&&(n.pec=n.ec,f+="&ec="+n.ec+"&ecf="+
# n.ecf),z=e("ctb",b),"ld"!==k||b||a.markers?a.markers&&a.isl&&!l&&b&&B(a.markers,e("t",b)):(a.markers={},B(a.markers,e("t",b))),e("t",b,{}));a.tag&&a.tag().length&&(f+="&csmtags="+a.tag().join("|"),a.tag=P());n=a.viz||[];(r=n.length)&&(f+="&viz="+n.splice(0,r).join("|"));u(d.ue_pty)||(f+="&pty="+d.ue_pty+"&spty="+d.ue_spty+"&pti="+d.ue_pti);a.tabid&&(f+="&tid="+a.tabid);a.aftb&&(f+="&aftb=1");!a._ui||b&&b!=s||(f+=a._ui());f+="&lob="+(d.ue_lob||"0");a.a=f;m(f,k,z,l,b&&"string"===typeof b&&-1!==b.indexOf("csa:"))}}
# function ca(a){var b=h.ue_csm_markers||{},c;for(c in b)b[v](c)&&y(c,a,F,b[c])}function A(a,b,c){c=c||h;if(c[V])c[V](a,b,!1);else if(c[W])c[W]("on"+a,b)}function T(a,b,c){c=c||h;if(c[X])c[X](a,b,!1);else if(c[Y])c[Y]("on"+a,b)}function Z(){function a(){d.onUl()}function b(a){return function(){c[a]||(c[a]=1,S(a))}}var c={},e,g;d.onLd=b("ld");d.onLdEnd=b("ld");d.onUl=b("ul");e={stop:b("os")};h.chrome?(A(G,a),L.push(a)):e[G]=d.onUl;for(g in e)e[v](g)&&R(0,h,g,e[g]);d.ue_viz&&ue_viz();A("load",d.onLd);
# y("ue")}function ba(e,b,c){var g=d.ue_mbl,p=h.csa,m=p&&p("SPA"),p=p&&p("PageTiming");g&&g.ajax&&g.ajax(b,c);m&&p&&(m("newPage",{requestId:e,transitionType:"soft"}),p("mark","transitionStart",b));a.tag("ajax-transition")}d.ueinit=(d.ueinit||0)+1;var a=d.ue=d.ue||{};a.t0=h.aPageStart||d.ue_t0;a.id=d.ue_id;a.url=d.ue_url;a.rid=d.ue_id;a.a="";a.b="";a.h={};a.s=1;a.t={};a.sc={};a.iel=[];a.ielf=[];a.viz=[];a.v="0.290981.0";a.paused=!1;var v="hasOwnProperty",G="beforeunload",K="on"+G,V="addEventListener",
# X="removeEventListener",W="attachEvent",Y="detachEvent",da={cf:"criticalFeature",af:"aboveTheFold",fn:"functional",fp:"firstPaint",fcp:"firstContentfulPaint",bb:"bodyBegin",be:"bodyEnd",ld:"loaded"},E=h.Date,C=h.performance||h.webkitPerformance,g=(C||{}).timing,x=(C||{}).navigation,M=(g||{}).navigationStart,w=d.ue_fpf,Q=0,U=0,L=[],D=0,F;a.oid=H(a.id);a.lid=H(a.id);a._t0=a.t0;a.tag=P();a.ifr=h.top!==h.self||h.frameElement?1:0;a.markers=null;a.attach=A;a.detach=T;if("000-0000000-8675309"===d.ue_sid){var $=
# I("cdn-rid"),aa=I("session-id");$&&aa&&O($,aa,"cdn")}d.uei=Z;d.ueh=R;d.ues=e;d.uet=y;d.uex=S;a.reset=O;a.pause=function(d){a.paused=d};Z()})(ue_csm,ue_csm.window,ue_csm.document);
#
#
# ue.stub(ue,"log");ue.stub(ue,"onunload");ue.stub(ue,"onflush");
# (function(b){function g(){var a={requestId:b.ue_id||"rid",server:b.ue_sn||"sn",obfuscatedMarketplaceId:b.ue_mid||"mid"};b.ue_sjslob&&(a.lob=b.ue_lob||"0");return a}var a=b.ue,h=1===b.ue_no_counters;a.cv={};a.cv.scopes={};a.cv.buffer=[];a.count=function(b,f,c){var e={},d=a.cv,g=c&&0===c.c;e.counter=b;e.value=f;e.t=a.d();c&&c.scope&&(d=a.cv.scopes[c.scope]=a.cv.scopes[c.scope]||{},e.scope=c.scope);if(void 0===f)return d[b];d[b]=f;d=0;c&&c.bf&&(d=1);h||(ue_csm.ue_sclog||!a.clog||0!==d||g?a.log&&a.log(e,
# "csmcount",{c:1,bf:d}):a.clog(e,"csmcount",{bf:d}));a.cv.buffer.push({c:b,v:f})};a.count("baselineCounter2",1);a&&a.event&&(a.event(g(),"csm","csm.CSMBaselineEvent.4"),a.count("nexusBaselineCounter",1,{bf:1}))})(ue_csm);
#
#
# (function(g,h,l){if("function"===typeof h.addEventListener&&"function"===typeof l.querySelectorAll){var e,r=["mouseenter","mouseleave"],t="click dblclick mousedown mouseover mouseout touchstart keydown keypress MSPointerDown pointerdown focusin".split(" ").concat(r),n=!1,p=[];var u=function(a){for(var b=[];a;)b.push(a),a=a.parentNode;return b};var q=function(a,b){var d=-1,c;for(c=0;c<b.length;c++)if(b[c]===a){d=c;break}return d};var v=function(a,b){a=q(a,b);0<=a&&b.splice(a,1)};var x=function(a){a=
# u(a);for(var b,d,c=0;c<a.length;c++)if(d=a[c],(b=d.nodeName)&&b!==l.nodeName){b=b.toLowerCase();if(d.id)return b+"#"+d.id+(f?">"+f:"");(d=d.getAttribute("class"))&&(b=b+"."+d.split(" ").join("."));var f=b+(f?">"+f:"")}return f};var y=function(a){return a.replace(/[^\w.:\-]/g,function(a){return"#"===a?"::":">"===a?":-":"_"})};var w=function(a,b){if(g.ue&&g.ue.count&&g.ueLogError){a=x(a);var d=y(a);var c="degraded"===b?"A UX degrading element has entered the viewport: "+a:"A "+b+" was not handled on element: "+
# a;g.ueLogError({m:c,fromOnError:1},{logLevel:"ERROR",attribution:a,message:c});b=["TNR","TNR:"+b,"TNR:"+d,"TNR:"+b+":"+d];for(e=0;e<b.length;e++)g.ue.count(b[e],(g.ue.count(b[e])||0)+1)}};var z=function(a){a=a.getBoundingClientRect();return a.top<a.bottom&&a.left<a.right&&0<=a.bottom&&a.top<=h.innerHeight&&0<=a.right&&a.left<=h.innerWidth};var m=function(){n||(n=!0,setTimeout(function(){[].forEach.call(l.querySelectorAll("[data-ux-degraded]"),function(a){z(a)?0>q(a,p)&&(p.push(a),w(a,"degraded")):
# v(a,p)});n=!1},250))};h.addEventListener("scroll",m);h.addEventListener("resize",m);m=function(a){var b=!1,d=0>q(a,r);l.addEventListener(a,function(c){if(!b){b=!0;var f=[],e=d?u(c.target):[c.target],g,h;for(g=0;g<e.length;g++){var k=e[g];k.getAttribute&&("mouseover"===a&&k===c.target&&((h=k.getAttribute("data-ux-jq-mouseenter"))||""===h)&&f.push(k),((h=k.getAttribute("data-ux-"+a))||""===h)&&f.push(k))}f.length?(c.ack=c.acknowledge=function(a){a=a||c.currentTarget;v(a,f)},setTimeout(function(){var c;
# for(c=0;c<f.length;c++)w(f[c],a);b=!1},250)):b=!1}},!0)};for(e=0;e<t.length;e++)m(t[e])}})(ue_csm,window,document);
#
#
# var ue_hoe = +new Date();
# }
# window.ueinit = window.ue_ihb;
#
#
# <!-- 8b5n1z5vk591pmrw0qccf5bfgqzik1gvr9yn -->
# window.ue && ue.count && ue.count('CSMLibrarySize', 12302)
#   </script>
#   <script>
#    if(typeof uet === 'function'){ uet('bb', 'LoadAds', {wb: 1}); }
#   </script>
#   <script>
#    window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadAds',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyBegin', 1718099834752);
#         }
#     })
#   </script>
#   <script>
#    window.ads_js_start = new Date().getTime();
# var imdbads = imdbads || {}; imdbads.cmd = imdbads.cmd || [];
#   </script>
#   <script id="ads_tarnhelm" src="https://m.media-amazon.com/images/S/sash/3BXfH142FQneV89.js">
#   </script>
#   <script id="crem_library" src="https://m.media-amazon.com/images/I/11QhRZqmoxL.js">
#   </script>
#   <script id="ads_doWithAds">
#    doWithAds = function(inside, failureMessage){
# if ('consoleLog' in window &&
# 'generic' in window &&
# 'ad_utils' in window &&
# 'custom' in window &&
# 'monitoring' in generic &&
# 'document_is_ready' in generic) {
# try{
# inside.call(this);
# }catch(e) {
# if ( window.ueLogError ) {
# if(typeof failureMessage !== 'undefined'){
# e.message = failureMessage;
# }
# e.attribution = "Advertising";
# e.logLevel = "ERROR";
# ueLogError(e);
# }
# if( (document.location.hash.match('debug=1')) &&
# (typeof failureMessage !== 'undefined') ){
# console.error(failureMessage);
# }
# }
# } else {
# if( (document.location.hash.match('debug=1')) &&
# (typeof failureMessage !== 'undefined') ){
# console.error(failureMessage);
# }
# }
# };
#   </script>
#   <script id="ads_monitoring_setup">
#    doWithAds(function(){
# generic.monitoring.set_forester_info("main");
# generic.monitoring.set_twilight_info(
# "main",
# "ID",
# "4c72776861ff0d97a8003c2132fa802bb2406212",
# "2024-06-11T09%3A57%3A14GMT",
# "https://s.media-imdb.com/twilight/?",
# "consumer");
# generic.monitoring.start_timing("page_load");
# generic.seconds_to_midnight = 75766;
# generic.days_to_midnight = 0.8769212961196899;
# },"Generic not defined, skipping monitoring setup.");
#   </script>
#   <script src="https://images-na.ssl-images-amazon.com/images/S/apesafeframe/ape/sf/desktop/DAsf-1.50.d327519.js">
#   </script>
#   <script id="ads_safeframe_setup">
#    doWithAds(function(){
# if (typeof DAsf != 'undefined' && typeof DAsf.registerCustomMessageListener === 'function') {
# var ad_utils = window.ad_utils;
# if (ad_utils) {
# if (ad_utils.update_ad_details) {
# DAsf.registerCustomMessageListener('updateAdDetails', window.ad_utils.update_ad_details);
# }
# if (ad_utils.set_partner) {
# DAsf.registerCustomMessageListener('setPartner', window.ad_utils.set_partner);
# }
# DAsf.registerCustomMessageListener('sendMetrics', window.generic.monitoring.update_sf_slot_metrics);
# if (ad_utils.expand_overlay) {
# DAsf.registerCustomMessageListener('expand', window.ad_utils.expand_overlay);
# }
# if (ad_utils.collapse_overlay) {
# DAsf.registerCustomMessageListener('collapse', window.ad_utils.collapse_overlay);
# }
# }
# }
# },"ads js missing, skipping safeframe setup.");
#   </script>
#   <script id="ads_general_setup">
#    doWithAds(function(){
# if (ad_utils && typeof CREM != 'undefined') {
# ad_utils.CREM = CREM;
# }
# generic.monitoring.record_metric("ads_js_request_to_done", (new Date().getTime()) - window.ads_js_start);
# generic.send_csm_head_metrics && generic.send_csm_head_metrics();
# if (ad_utils && ad_utils.set_slots_on_page) {
# ad_utils.set_slots_on_page({ 'inlinebottom_refresh':1, 'inlinebottom':1, 'inline20':1, 'sis_pixel':1, 'inline20_refresh':1, 'inline40_refresh':1, 'inline40':1 });
# }
# custom.full_page.data_url = "https://m.media-amazon.com/images/S/sash/LjmweAjwgV1r2dK.js";
# consoleLog('advertising initialized','ads');
# },"ads js missing, skipping general setup.");
#   </script>
#   <script>
#    doWithAds(function() {
# if (ad_utils && ad_utils.ads_header && ad_utils.ads_header.done) {
# ad_utils.ads_header.done();
# }
# });
#   </script>
#   <link href="https://m.media-amazon.com/images/S/sash/Wx8WCzkjLY4P$JX.css" rel="stylesheet"/>
#   <script>
#    if(typeof uet === 'function'){ uet('be', 'LoadAds', {wb: 1}); }
#   </script>
#   <script>
#    window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadAds',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyEnd', 1718099834752);
#         }
#     })
#   </script>
#   <script>
#    if(typeof uex === 'function'){ uex('ld', 'LoadAds', {wb: 1}); }
#   </script>
#   <script>
#    window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadAds',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToLoaded', 1718099834752);
#         }
#     })
#   </script>
#   <script>
#    if(typeof uet === 'function'){ uet('bb', 'LoadStyledComponents', {wb: 1}); }
#   </script>
#   <script>
#    window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadStyledComponents',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyBegin', 1718099834752);
#         }
#     })
#   </script>
#   <script>
#    if(typeof uet === 'function'){ uet('be', 'LoadStyledComponents', {wb: 1}); }
#   </script>
#   <script>
#    window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadStyledComponents',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyEnd', 1718099834752);
#         }
#     })
#   </script>
#   <script>
#    if(typeof uex === 'function'){ uex('ld', 'LoadStyledComponents', {wb: 1}); }
#   </script>
#   <script>
#    window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadStyledComponents',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToLoaded', 1718099834752);
#         }
#     })
#   </script>
#   <script>
#    if(typeof uet === 'function'){ uet('bb', 'LoadFonts', {wb: 1}); }
#   </script>
#   <script>
#    window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadFonts',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyBegin', 1718099834752);
#         }
#     })
#   </script>
#   <script>
#    (function (win) {
#     window.PLAID_LOAD_FONTS_FIRED = true;
#
#     if (typeof win.FontFace !== "undefined"
#         && typeof win.Promise !== "undefined") {
#         if (win.ue) {
#             win.uet("bb", "LoadFonts", { wb: 1 });
#         }
#         var allowableLoadTime = 1500;
#         var startTimeInt = +new Date();
#         var fonts = [
#
#     new FontFace(
#         'Roboto',
#         'url(https://m.media-amazon.com/images/G/01/IMDb/cm9ib3Rv._TTW_.woff2)',
#         {style: "normal", weight: 400}
#     ),
#     new FontFace(
#         'Roboto',
#         'url(https://m.media-amazon.com/images/G/01/IMDb/cm9ib3RvTWVk._TTW_.woff2)',
#         {style: "normal", weight: 500}
#     ),
#     new FontFace(
#         'Roboto',
#         'url(https://m.media-amazon.com/images/G/01/IMDb/cm9ib3RvQm9sZA._TTW_.woff2)',
#         {style: "normal", weight: 600}
#     )
#         ];
#
#         var loadPromises = [];
#         for (var i = 0; i < fonts.length; i++) {
#             loadPromises.push(fonts[i].load());
#         }
#
#         win.Promise.all(loadPromises).then(function() {
#             var loadTimeInt = +new Date();
#             var fontLoadedCount = 0;
#             if ((loadTimeInt - startTimeInt) <= allowableLoadTime) {
#                 for (var j = 0; j < fonts.length; j++) {
#                     win.document.fonts.add(fonts[j]);
#                     fontLoadedCount++;
#                 }
#             }
#             if (win.ue) {
#                 win.ue.count("font-loaded", fontLoadedCount);
#                 win.uet("be", "LoadFonts", { wb: 1 });
#                 win.uex("ld", "LoadFonts", { wb: 1 });
#             }
#         }).catch(function() {
#             if (win.ue) {
#                 win.ue.count("font-loaded", 0);
#             }
#         });
#     } else {
#         if (win.ue) {
#             win.ue.count("font-load-not-attempted", 1);
#         }
#     }
# })(window);
#   </script>
#   <script>
#    if(typeof uet === 'function'){ uet('be', 'LoadFonts', {wb: 1}); }
#   </script>
#   <script>
#    window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadFonts',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyEnd', 1718099834752);
#         }
#     })
#   </script>
#   <script>
#    if(typeof uex === 'function'){ uex('ld', 'LoadFonts', {wb: 1}); }
#   </script>
#   <script>
#    window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadFonts',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToLoaded', 1718099834752);
#         }
#     })
#   </script>
#   <script>
#    if(typeof uet === 'function'){ uet('bb', 'LoadIcons', {wb: 1}); }
#   </script>
#   <script>
#    window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadIcons',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyBegin', 1718099834752);
#         }
#     })
#   </script>
#   <link href="https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/favicon_desktop_32x32._CB1582158068_.png" rel="icon" sizes="32x32"/>
#   <link href="https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/favicon_iPad_retina_167x167._CB1582158068_.png" rel="icon" sizes="167x167"/>
#   <link href="https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/favicon_iPhone_retina_180x180._CB1582158069_.png" rel="icon" sizes="180x180"/>
#   <link href="https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/apple-touch-icon-mobile._CB479963088_.png" rel="apple-touch-icon"/>
#   <link href="https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/apple-touch-icon-mobile-76x76._CB479962152_.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/apple-touch-icon-mobile-120x120._CB479963088_.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/apple-touch-icon-web-152x152._CB479963088_.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="https://m.media-amazon.com/images/G/01/imdb/images-ANDW73HA/android-mobile-196x196._CB479962153_.png" rel="shortcut icon" sizes="196x196"/>
#   <link href="/opensearch.xml" rel="search" title="IMDb" type="application/opensearchdescription+xml"/>
#   <script>
#    if(typeof uet === 'function'){ uet('be', 'LoadIcons', {wb: 1}); }
#   </script>
#   <script>
#    window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadIcons',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyEnd', 1718099834752);
#         }
#     })
#   </script>
#   <script>
#    if(typeof uex === 'function'){ uex('ld', 'LoadIcons', {wb: 1}); }
#   </script>
#   <script>
#    window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadIcons',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToLoaded', 1718099834752);
#         }
#     })
#   </script>
#   <script>
#    window.ue_ihe = (window.ue_ihe || 0) + 1;
# if (window.ue_ihe === 1) {
# (function(c){c&&1===c.ue_jsmtf&&"object"===typeof c.P&&"function"===typeof c.P.when&&c.P.when("mshop-interactions").execute(function(e){"object"===typeof e&&"function"===typeof e.addListener&&e.addListener(function(b){"object"===typeof b&&"ORIGIN"===b.dataSource&&"number"===typeof b.clickTime&&"object"===typeof b.events&&"number"===typeof b.events.pageVisible&&(c.ue_jsmtf_interaction={pv:b.events.pageVisible,ct:b.clickTime})})})})(ue_csm);
# (function(c,e,b){function m(a){f||(f=d[a.type].id,"undefined"===typeof a.clientX?(h=a.pageX,k=a.pageY):(h=a.clientX,k=a.clientY),2!=f||l&&(l!=h||n!=k)?(r(),g.isl&&e.setTimeout(function(){p("at",g.id)},0)):(l=h,n=k,f=0))}function r(){for(var a in d)d.hasOwnProperty(a)&&g.detach(a,m,d[a].parent)}function s(){for(var a in d)d.hasOwnProperty(a)&&g.attach(a,m,d[a].parent)}function t(){var a="";!q&&f&&(q=1,a+="&ui="+f);return a}var g=c.ue,p=c.uex,q=0,f=0,l,n,h,k,d={click:{id:1,parent:b},mousemove:{id:2,
# parent:b},scroll:{id:3,parent:e},keydown:{id:4,parent:b}};g&&p&&(s(),g._ui=t)})(ue_csm,window,document);
#
#
# (function(s,l){function m(b,e,c){c=c||new Date(+new Date+t);c="expires="+c.toUTCString();n.cookie=b+"="+e+";"+c+";path=/"}function p(b){b+="=";for(var e=n.cookie.split(";"),c=0;c<e.length;c++){for(var a=e[c];" "==a.charAt(0);)a=a.substring(1);if(0===a.indexOf(b))return decodeURIComponent(a.substring(b.length,a.length))}return""}function q(b,e,c){if(!e)return b;-1<b.indexOf("{")&&(b="");for(var a=b.split("&"),f,d=!1,h=!1,g=0;g<a.length;g++)f=a[g].split(":"),f[0]==e?(!c||d?a.splice(g,1):(f[1]=c,a[g]=
# f.join(":")),h=d=!0):2>f.length&&(a.splice(g,1),h=!0);h&&(b=a.join("&"));!d&&c&&(0<b.length&&(b+="&"),b+=e+":"+c);return b}var k=s.ue||{},t=3024E7,n=ue_csm.document||l.document,r=null,d;a:{try{d=l.localStorage;break a}catch(u){}d=void 0}k.count&&k.count("csm.cookieSize",document.cookie.length);k.cookie={get:p,set:m,updateCsmHit:function(b,e,c){try{var a;if(!(a=r)){var f;a:{try{if(d&&d.getItem){f=d.getItem("csm-hit");break a}}catch(k){}f=void 0}a=f||p("csm-hit")||"{}"}a=q(a,b,e);r=a=q(a,"t",+new Date);
# try{d&&d.setItem&&d.setItem("csm-hit",a)}catch(h){}m("csm-hit",a,c)}catch(g){"function"==typeof l.ueLogError&&ueLogError(Error("Cookie manager: "+g.message),{logLevel:"WARN"})}}}})(ue_csm,window);
#
#
# (function(l,e){function c(b){b="";var c=a.isBFT?"b":"s",d=""+a.oid,g=""+a.lid,h=d;d!=g&&20==g.length&&(c+="a",h+="-"+g);a.tabid&&(b=a.tabid+"+");b+=c+"-"+h;b!=f&&100>b.length&&(f=b,a.cookie?a.cookie.updateCsmHit(m,b+("|"+ +new Date)):e.cookie="csm-hit="+b+("|"+ +new Date)+n+"; path=/")}function p(){f=0}function d(b){!0===e[a.pageViz.propHid]?f=0:!1===e[a.pageViz.propHid]&&c({type:"visible"})}var n="; expires="+(new Date(+new Date+6048E5)).toGMTString(),m="tb",f,a=l.ue||{},k=a.pageViz&&a.pageViz.event&&
# a.pageViz.propHid;a.attach&&(a.attach("click",c),a.attach("keyup",c),k||(a.attach("focus",c),a.attach("blur",p)),k&&(a.attach(a.pageViz.event,d,e),d({})));a.aftb=1})(ue_csm,ue_csm.document);
#
#
# ue_csm.ue.stub(ue,"impression");
#
#
# ue.stub(ue,"trigger");
#
#
# if(window.ue&&uet) { uet('bb'); }
#
# }
#
# window.ue && ue.count && ue.count('CSMLibrarySize', 3172)
#   </script>
#   <link as="style" href="https://dqpnq362acqdi.cloudfront.net/_next/static/css/bd4a60fb20e55bf2.css" rel="preload"/>
#   <link data-n-g="" href="https://dqpnq362acqdi.cloudfront.net/_next/static/css/bd4a60fb20e55bf2.css" rel="stylesheet"/>
#   <noscript data-n-css="">
#   </noscript>
#   <script defer="" nomodule="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/webpack-c6cb93025a6d91e4.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/framework-735a6db3a2e8e4c5.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/main-e10dbeb41a067f4f.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/pages/_app-e3200bec8b3be994.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/3169-e9653c390070f900.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/9181-8cf61807cde31f06.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/3094-3007b658baf5e62f.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/4187-911f269aea6ba4a1.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/3130-601ff05a25b1069f.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/2050-ddb1f08945f05ef4.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/1103-2888f3622c4f67f9.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/5959-eeb0c2aa64433d93.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/3037-b46aa07fbb1ff329.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/6741-708b2f6376188af9.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/4791-60b97cb9322f90a6.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/1401-6cd6289916eb14ec.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/7030-802999c6c12bfdf1.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/6160-bfa57518a16df419.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/7329-a6541defa736a709.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/7334-665b61b6efed6771.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/3165-d1ec6f25f838fe9a.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/1746-ae909340ef8cd26d.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/3296-fcadc4f94030168c.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/chunks/pages/chart/top-ee9505b651115e97.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/dS6jMUWky0yCVAoDxNAG0/_buildManifest.js">
#   </script>
#   <script defer="" src="https://dqpnq362acqdi.cloudfront.net/_next/static/dS6jMUWky0yCVAoDxNAG0/_ssgManifest.js">
#   </script>
#   <style data-styled="active" data-styled-version="6.1.0">
#   </style>
#  </head>
#  <body>
#   <div>
#    <img alt="" height="1" onload="window.ue_sbl &amp;&amp; window.ue_sbl();" src="//fls-na.amazon.com/1/batch/1/OP/A1EVAM02EL8SFB:137-3713988-0011656:RGRS4XPFBK3JY7C1RV7P$uedata=s:%2Fuedata%2Fuedata%3Fstaticb%26id%3DRGRS4XPFBK3JY7C1RV7P:0" style="display:none;visibility:hidden;" width="1"/>
#    <script>
#     !function(){function n(n,t){var r=i(n);return t&&(r=r("instance",t)),r}var r=[],c=0,i=function(t){return function(){var n=c++;return r.push([t,[].slice.call(arguments,0),n,{time:Date.now()}]),i(n)}};n._s=r,this.csa=n}();;
# csa('Config', {});
# if (window.csa) {
#     csa("Config", {
#
#         'Events.Namespace': 'csa',
#         'ObfuscatedMarketplaceId': 'A1EVAM02EL8SFB',
#         'Events.SushiEndpoint': 'https://unagi.amazon.com/1/events/com.amazon.csm.csa.prod',
#         'CacheDetection.RequestID': "RGRS4XPFBK3JY7C1RV7P",
#         'CacheDetection.Callback': window.ue && ue.reset,
#         'LCP.elementDedup': 1,
#         'lob': '6'
#     });
#
#     csa("Events")("setEntity", {
#         page: {requestId: "RGRS4XPFBK3JY7C1RV7P", meaningful: "interactive"},
#         session: {id: "137-3713988-0011656"}
#     });
# }
# !function(r){var e,i,o="splice",u=r.csa,f={},c={},a=r.csa._s,s=0,l=0,g=-1,h={},v={},d={},n=Object.keys,p=function(){};function t(n,t){return u(n,t)}function m(n,t){var r=c[n]||{};k(r,t),c[n]=r,l++,S(U,0)}function w(n,t,r){var i=!0;return t=D(t),r&&r.buffered&&(i=(d[n]||[]).every(function(n){return!1!==t(n)})),i?(h[n]||(h[n]=[]),h[n].push(t),function(){!function(n,t){var r=h[n];r&&r[o](r.indexOf(t),1)}(n,t)}):p}function b(n,t){if(t=D(t),n in v)return t(v[n]),p;return w(n,function(n){return t(n),!1})}function y(n,t){if(u("Errors")("logError",n),f.DEBUG)throw t||n}function E(){return Math.abs(4294967295*Math.random()|0).toString(36)}function D(n,t){return function(){try{return n.apply(this,arguments)}catch(n){y(n.message||n,n)}}}function S(n,t){return r.setTimeout(D(n),t)}function U(){for(var n=0;n<a.length;){var t=a[n],r=t[0]in c;if(!r&&!i)return void(s=a.length);r?(a[o](s=n,1),I(t)):n++}g=l}function I(n){var t=c[n[0]],r=n[1],i=r[0];if(!t||!t[i])return y("Undefined function: "+t+"/"+i);e=n[3],c[n[2]]=t[i].apply(t,r.slice(1))||{},e=0}function O(){i=1,U()}function k(t,r){n(r).forEach(function(n){t[n]=r[n]})}b("$beforeunload",O),m("Config",{instance:function(n){k(f,n)}}),u.plugin=D(function(n){n(t)}),t.config=f,t.register=m,t.on=w,t.once=b,t.blank=p,t.emit=function(n,t,r){for(var i=h[n]||[],e=0;e<i.length;)!1===i[e](t)?i[o](e,1):e++;v[n]=t||{},r&&r.buffered&&(d[n]||(d[n]=[]),100<=d[n].length&&d[n].shift(),d[n].push(t||{}))},t.UUID=function(){return[E(),E(),E(),E()].join("-")},t.time=function(n){var t=e?new Date(e.time):new Date;return"ISO"===n?t.toISOString():t.getTime()},t.error=y,t.warn=function(n,t){if(u("Errors")("logWarn",n),f.DEBUG)throw t||n},t.exec=D,t.timeout=S,t.interval=function(n,t){return r.setInterval(D(n),t)},(t.global=r).csa._s.push=function(n){n[0]in c&&(!a.length||i)?(I(n),a.length&&g!==l&&U()):a[o](s++,0,n)},U(),S(function(){S(O,f.SkipMissingPluginsTimeout||5e3)},1)}("undefined"!=typeof window?window:global);csa.plugin(function(o){var f="addEventListener",e="requestAnimationFrame",t=o.exec,r=o.global,u=o.on;o.raf=function(n){if(r[e])return r[e](t(n))},o.on=function(n,e,t,r){if(n&&"function"==typeof n[f]){var i=o.exec(t);return n[f](e,i,r),function(){n.removeEventListener(e,i,r)}}return"string"==typeof n?u(n,e,t,r):o.blank}});csa.plugin(function(o){var t,n,r={},e="localStorage",c="sessionStorage",a="local",i="session",u=o.exec;function s(e,t){var n;try{r[t]=!!(n=o.global[e]),n=n||{}}catch(e){r[t]=!(n={})}return n}function f(){t=t||s(e,a),n=n||s(c,i)}function l(e){return e&&e[i]?n:t}o.store=u(function(e,t,n){f();var o=l(n);return e?t?void(o[e]=t):o[e]:Object.keys(o)}),o.storageSupport=u(function(){return f(),r}),o.deleteStored=u(function(e,t){f();var n=l(t);if("function"==typeof e)for(var o in n)n.hasOwnProperty(o)&&e(o,n[o])&&delete n[o];else delete n[e]})});csa.plugin(function(n){n.types={ovl:function(n){var r=[];if(n)for(var i in n)n.hasOwnProperty(i)&&r.push(n[i]);return r}}});csa.plugin(function(c){var e=c.config;function n(n){return function(e){c("Metrics",{producerId:"csa",dimensions:{message:e}})("recordMetric",n,1)}}function r(r){var o,t,l=c("Events",{producerId:r.producerId,lob:e.lob||"0"}),u=["name","type","csm","adb"],i={url:"pageURL",file:"f",line:"l",column:"c"};this.log=function(e){if(!function(e){if(!e)return!0;for(var n in e)return!1;return!0}(e)){var n=r.logOptions||{ent:{page:["pageType","subPageType","requestId"]}};l("log",function(n){return o=c.UUID(),t={messageId:o,schemaId:r.schemaId||"<ns>.Error.6",errorMessage:n.m||null,attribution:n.attribution||null,logLevel:"FATAL",url:null,file:null,line:null,column:null,stack:n.s||[],context:n.cinfo||{},metadata:{}},n.logLevel&&(t.logLevel=""+n.logLevel),u.forEach(function(e){n[e]&&(t.metadata[e]=n[e])}),"INFO"===n.logLevel||Object.keys(i).forEach(function(e){"number"!=typeof n[i[e]]&&"string"!=typeof n[i[e]]||(t[e]=""+n[i[e]])}),t}(e),n)}}}c.register("Errors",{instance:function(e){return new r(e||{})},logError:n("jsError"),logWarn:n("jsWarn")})});csa. ...
#
# var ue_csa_ss_tag = false;
# csa.plugin(function(b){var a=b.global,e=a.uet,f=a.uex,c=a.ue,d=a.Object,g=0,h={largestContentfulPaint:"lcp",speedIndex:"si",atfSpeedIndex:"atfsi",visuallyLoaded50:"vl50",visuallyLoaded90:"vl90",visuallyLoaded100:"vl100"},l="perfNo perfYes browserQuiteFn browserQuiteUd browserQuiteLd browserQuiteMut mutObsNo mutObsYes mutObsActive startVL endVL".split(" ");b&&e&&f&&d.keys&&c&&(b.once("$ditched.beforemitigation",function(){g=1}),d.keys(h).forEach(function(k){b.on("$timing:"+k,function(b){var a=h[k];
# if(c.isl||g){var d="csa:"+a;e(a,d,void 0,b);f("at",d)}else e(a,void 0,void 0,b)})}),a.ue_csa_ss_tag||l.forEach(function(a){b.on("$csmTag:"+a,function(){c.tag&&c.tag(a);(c.isl||g)&&f("at","csa:"+a)},{buffered:1})}))});
#    </script>
#    <script type="text/javascript">
#     (function(){function l(a){for(var c=b.location.search.substring(1).split("&"),e=0;e<c.length;e++){var d=c[e].split("=");if(d[0]===a)return d[1]}}window.amzn=window.amzn||{};amzn.copilot=amzn.copilot||{};var b=window,f=document,g=b.P||b.AmazonUIPageJS,h=f.head||f.getElementsByTagName("head")[0],m=0,n=0;amzn.copilot.checkCoPilotSession=function(){f.cookie.match("cpidv")&&("undefined"!==typeof jQuery&&k(jQuery),g&&g.when&&g.when("jQuery").execute(function(a){k(a)}),b.amznJQ&&b.amznJQ.available&&b.amznJQ.available("jQuery",
# function(){k(jQuery)}),b.jQuery||g||b.amznJQ||q())};var q=function(){m?b.ue&&"function"===typeof b.ue.count&&b.ue.count("cpJQUnavailable",1):(m=1,f.addEventListener?f.addEventListener("DOMContentLoaded",amzn.copilot.checkCoPilotSession,!1):f.attachEvent&&f.attachEvent("onreadystatechange",function(){"complete"===f.readyState&&amzn.copilot.checkCoPilotSession()}))},k=function(a){if(!n){n=1;amzn.copilot.jQuery=a;a=l("debugJS");var c="https:"===b.location.protocol?1:0,e=1;url="/gp/copilot/handlers/copilot_strings_resources.html";
# window.texas&&texas.locations&&(url=texas.locations.makeUrl(url));g&&g.AUI_BUILD_DATE&&(e=0);amzn.copilot.jQuery.ajax&&amzn.copilot.jQuery.ajax({url:url,dataType:"json",data:{isDebug:a,isSecure:c,includeAUIP:e},success:function(a){amzn.copilot.vip=a.serviceEndPoint;amzn.copilot.enableMultipleTabSession=a.isFollowMe;r(a)},error:function(){b.ue.count("cpLoadResourceError",1)}})}},r=function(a){var c=amzn.copilot.jQuery,e=function(){amzn.copilot.setup(c.extend({isContinuedSession:!0},a))};a.CSSUrls&&
# c.each(a.CSSUrls[0],function(a,c){var b=f.createElement("link");b.type="text/css";b.rel="stylesheet";b.href=c;h.appendChild(b)});a.CSSTag&&s(a.CSSTag);if(a.JSUrls){var d=l("forceSynchronousJS"),b=a.JSUrls[0];c.each(b,function(a,c){a===b.length-1?p(c,d,e):p(c,d)})}a.JSTag&&(t(a.JSTag),P.when("CSCoPilotPresenterAsset").execute(function(){e()}))},t=function(a){var c=f.createElement("div");c.innerHTML=a;a=0;for(var b=c.children.length;a<b;a++){var d=f.createElement("script");d.type="text/javascript";
# d.innerHTML=c.children[a].innerHTML;h.appendChild(d)}},s=function(a){var b=f.createElement("div");b.innerHTML=a;a=0;for(var e=b.children.length;a<e;a++)h.appendChild(b.children[a])},p=function(a,b,e){var d=f.createElement("script");d.type="text/javascript";d.src=a;d.async=b?!1:!0;e&&(d.onload=e);h.appendChild(d)}})();
#
# amzn.copilot.checkCoPilotSession();
#    </script>
#    <script>
#     window.ue && ue.count && ue.count('CSMLibrarySize', 18810)
#    </script>
#   </div>
#   <div data-reactroot="" id="__next">
#    <script>
#     if(typeof uet === 'function'){ uet('bb', 'imdbHeader', {wb: 1}); }
#    </script>
#    <nav class="sc-eKYSwk kjzUkx imdb-header imdb-header--react celwidget" data-csa-c-id="aj0lc7-y9uuw8-2m5a5q-95d84b" id="imdbHeader">
#     <div class="imdb-header__login-state-node" id="nblogin">
#     </div>
#     <div class="ipc-page-content-container ipc-page-content-container--center navbar__inner" role="presentation">
#      <label aria-disabled="false" aria-haspopup="true" aria-label="Open Navigation Drawer" class="ipc-responsive-button ipc-btn--theme-baseAlt ipc-responsive-button--transition-l ipc-btn--on-textPrimary ipc-responsive-button--single-padding sc-oefmM dfECtA hamburger__icon" for="imdbHeader-navDrawer" id="imdbHeader-navDrawerOpen" role="button" tabindex="0">
#       <svg class="ipc-icon ipc-icon--menu ipc-responsive-button__icon" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#        <path d="M0 0h24v24H0V0z" fill="none">
#        </path>
#        <path d="M4 18h16c.55 0 1-.45 1-1s-.45-1-1-1H4c-.55 0-1 .45-1 1s.45 1 1 1zm0-5h16c.55 0 1-.45 1-1s-.45-1-1-1H4c-.55 0-1 .45-1 1s.45 1 1 1zM3 7c0 .55.45 1 1 1h16c.55 0 1-.45 1-1s-.45-1-1-1H4c-.55 0-1 .45-1 1z">
#        </path>
#       </svg>
#       <span class="ipc-responsive-button__text">
#        Menu
#       </span>
#      </label>
#      <input aria-hidden="true" class="drawer__state" hidden="" id="imdbHeader-navDrawer" name="imdbHeader-navDrawer" type="checkbox"/>
#      <aside class="sc-carGes bVsgci drawer hamburger__drawer imdb-header__nav-drawer" data-testid="drawer" role="presentation">
#       <div aria-hidden="true" class="drawer__panel" data-testid="panel" role="presentation">
#        <div class="drawer__panelHeader" data-testid="panel-header" role="presentation">
#         <a href="/?ref_=nv_home">
#          <svg class="ipc-logo drawer-logo" height="56" version="1.1" viewbox="0 0 64 32" width="98" xmlns="http://www.w3.org/2000/svg">
#           <g fill="#F5C518">
#            <rect height="100%" rx="4" width="100%" x="0" y="0">
#            </rect>
#           </g>
#           <g fill="#000000" fill-rule="nonzero" transform="translate(8.000000, 7.000000)">
#            <polygon points="0 18 5 18 5 0 0 0">
#            </polygon>
#            <path d="M15.6725178,0 L14.5534833,8.40846934 L13.8582008,3.83502426 C13.65661,2.37009263 13.4632474,1.09175121 13.278113,0 L7,0 L7,18 L11.2416347,18 L11.2580911,6.11380679 L13.0436094,18 L16.0633571,18 L17.7583653,5.8517865 L17.7707076,18 L22,18 L22,0 L15.6725178,0 Z">
#            </path>
#            <path d="M24,18 L24,0 L31.8045586,0 C33.5693522,0 35,1.41994415 35,3.17660424 L35,14.8233958 C35,16.5777858 33.5716617,18 31.8045586,18 L24,18 Z M29.8322479,3.2395236 C29.6339219,3.13233348 29.2545158,3.08072342 28.7026524,3.08072342 L28.7026524,14.8914865 C29.4312846,14.8914865 29.8796736,14.7604764 30.0478195,14.4865461 C30.2159654,14.2165858 30.3021941,13.486105 30.3021941,12.2871637 L30.3021941,5.3078959 C30.3021941,4.49404499 30.272014,3.97397442 30.2159654,3.74371416 C30.1599168,3.5134539 30.0348852,3.34671372 29.8322479,3.2395236 Z">
#            </path>
# ...
# (p&&n(p,!0),c());clearInterval(f);s.detach&&s.detach("mousemove",n,e)},ready:function(){return a.ue_cel&&a.ue_cel.log},reset:function(){v=[];C=[];k=0;p=null}}}(window.performance),a.ue_cel&&a.ue_cel.registerModule("mouse move module",a.ue_mmm))})(ue_csm);
#
#
#
#
# ue_csm.ue_unrt = 1500;
# (function(d,b,t){function u(a,g){var c=a.srcElement||a.target||{},b={k:v,t:g.t,dt:g.dt,x:a.pageX,y:a.pageY,p:e.getXPath(c),n:c.nodeName};a.button&&(b.b=a.button);c.type&&(b.ty=c.type);c.href&&(b.r=e.extractStringValue(c.href));c.id&&(b.i=c.id);c.className&&c.className.split&&(b.c=c.className.split(/\s+/));h+=1;e.getFirstAscendingWidget(c,function(a){b.wd=a;d.ue.log(b,r)})}function w(a){if(!x(a.srcElement||a.target)){m+=1;n=!0;var g=f=d.ue.d(),c;p&&"function"===typeof p.now&&a.timeStamp&&(c=p.now()-
# a.timeStamp,c=parseFloat(c.toFixed(2)));s=b.setTimeout(function(){u(a,{t:g,dt:c})},y)}}function z(a){if(a){var b=a.filter(A);a.length!==b.length&&(q=!0,k=d.ue.d(),n&&q&&(k&&f&&d.ue.log({k:B,t:f,m:Math.abs(k-f)},r),l(),q=!1,k=0))}}function A(a){if(!a)return!1;var b="characterData"===a.type?a.target.parentElement:a.target;if(!b||!b.hasAttributes||!b.attributes)return!1;var c={"class":"gw-clock gw-clock-aria s-item-container-height-auto feed-carousel using-mouse kfs-inner-container".split(" "),id:["dealClock",
# "deal_expiry_timer","timer"],role:["timer"]},d=!1;Object.keys(c).forEach(function(a){var e=b.attributes[a]?b.attributes[a].value:"";(c[a]||"").forEach(function(a){-1!==e.indexOf(a)&&(d=!0)})});return d}function x(a){if(!a)return!1;var b=(e.extractStringValue(a.nodeName)||"").toLowerCase(),c=(e.extractStringValue(a.type)||"").toLowerCase(),d=(e.extractStringValue(a.href)||"").toLowerCase();a=(e.extractStringValue(a.id)||"").toLowerCase();var f="checkbox color date datetime-local email file month number password radio range reset search tel text time url week".split(" ");
# if(-1!==["select","textarea","html"].indexOf(b)||"input"===b&&-1!==f.indexOf(c)||"a"===b&&-1!==d.indexOf("http")||-1!==["sitbreaderrightpageturner","sitbreaderleftpageturner","sitbreaderpagecontainer"].indexOf(a))return!0}function l(){n=!1;f=0;b.clearTimeout(s)}function C(){b.ue.onunload(function(){ue.count("armored-cxguardrails.unresponsive-clicks.violations",h);ue.count("armored-cxguardrails.unresponsive-clicks.violationRate",h/m*100||0)})}if(b.MutationObserver&&b.addEventListener&&Object.keys&&
# d&&d.ue&&d.ue.log&&d.ue_unrt&&d.ue_utils){var y=d.ue_unrt,r="cel",v="unr_mcm",B="res_mcm",p=b.performance,e=d.ue_utils,n=!1,f=0,s=0,q=!1,k=0,h=0,m=0;b.addEventListener&&(b.addEventListener("mousedown",w,!0),b.addEventListener("beforeunload",l,!0),b.addEventListener("visibilitychange",l,!0),b.addEventListener("pagehide",l,!0));b.ue&&b.ue.event&&b.ue.onSushiUnload&&b.ue.onunload&&C();(new MutationObserver(z)).observe(t,{childList:!0,attributes:!0,characterData:!0,subtree:!0})}})(ue_csm,window,document);
#
#
# ue_csm.ue.exec(function(g,e){if(e.ue_err){var f="";e.ue_err.errorHandlers||(e.ue_err.errorHandlers=[]);e.ue_err.errorHandlers.push({name:"fctx",handler:function(a){if(!a.logLevel||"FATAL"===a.logLevel)if(f=g.getElementsByTagName("html")[0].innerHTML){var b=f.indexOf("var ue_t0=ue_t0||+new Date();");if(-1!==b){var b=f.substr(0,b).split(String.fromCharCode(10)),d=Math.max(b.length-10-1,0),b=b.slice(d,b.length-1);a.fcsmln=d+b.length+1;a.cinfo=a.cinfo||{};for(var c=0;c<b.length;c++)a.cinfo[d+c+1+""]=
# b[c]}b=f.split(String.fromCharCode(10));a.cinfo=a.cinfo||{};if(!(a.f||void 0===a.l||a.l in a.cinfo))for(c=+a.l-1,d=Math.max(c-5,0),c=Math.min(c+5,b.length-1);d<=c;d++)a.cinfo[d+1+""]=b[d]}}})}},"fatals-context")(document,window);
#
#
# (function(m,b){function c(k){function f(a){a&&"string"===typeof a&&(a=(a=a.match(/^(?:https?:)?\/\/(.*?)(\/|$)/i))&&1<a.length?a[1]:null,a&&a&&("number"===typeof e[a]?e[a]++:e[a]=1))}function d(a){var e=10,d=+new Date;a&&a.timeRemaining?e=a.timeRemaining():a={timeRemaining:function(){return Math.max(0,e-(+new Date-d))}};for(var c=b.performance.getEntries(),k=e;g<c.length&&k>n;)c[g].name&&f(c[g].name),g++,k=a.timeRemaining();g>=c.length?h(!0):l()}function h(a){if(!a){a=m.scripts;var c;if(a)for(var d=
# 0;d<a.length;d++)(c=a[d].getAttribute("src"))&&"undefined"!==c&&f(c)}0<Object.keys(e).length&&(p&&ue_csm.ue&&ue_csm.ue.event&&(a={domains:e,pageType:b.ue_pty||null,subPageType:b.ue_spty||null,pageTypeId:b.ue_pti||null},ue_csm.ue_sjslob&&(a.lob=ue_csm.ue_lob||"0"),ue_csm.ue.event(a,"csm","csm.CrossOriginDomains.2")),b.ue_ext=e)}function l(){!0===k?d():b.requestIdleCallback?b.requestIdleCallback(d):b.requestAnimationFrame?b.requestAnimationFrame(d):b.setTimeout(d,100)}function c(){if(b.performance&&
# b.performance.getEntries){var a=b.performance.getEntries();!a||0>=a.length?h(!1):l()}else h(!1)}var e=b.ue_ext||{};b.ue_ext||c();return e}function q(){setTimeout(c,r)}var s=b.ue_dserr||!1,p=!0,n=1,r=2E3,g=0;b.ue_err&&s&&(b.ue_err.errorHandlers||(b.ue_err.errorHandlers=[]),b.ue_err.errorHandlers.push({name:"ext",handler:function(b){if(!b.logLevel||"FATAL"===b.logLevel){var f=c(!0),d=[],h;for(h in f){var f=h,g=f.match(/amazon(\.com?)?\.\w{2,3}$/i);g&&1<g.length||-1!==f.indexOf("amazon-adsystem.com")||
# -1!==f.indexOf("amazonpay.com")||-1!==f.indexOf("cloudfront-labs.amazonaws.com")||d.push(h)}b.ext=d}}}));b.ue&&b.ue.isl?c():b.ue&&ue.attach&&ue.attach("load",q)})(document,window);
#
#
#
#
#
# var ue_wtc_c = 3;
# ue_csm.ue.exec(function(b,e){function l(){for(var a=0;a<f.length;a++)a:for(var d=s.replace(A,f[a])+g[f[a]]+t,c=arguments,b=0;b<c.length;b++)try{c[b].send(d);break a}catch(e){}g={};f=[];n=0;k=p}function u(){B?l(q):l(C,q)}function v(a,m,c){r++;if(r>w)d.count&&1==r-w&&(d.count("WeblabTriggerThresholdReached",1),b.ue_int&&console.error("Number of max call reached. Data will no longer be send"));else{var h=c||{};h&&-1<h.constructor.toString().indexOf(D)&&a&&-1<a.constructor.toString().indexOf(x)&&m&&-1<
# m.constructor.toString().indexOf(x)?(h=b.ue_id,c&&c.rid&&(h=c.rid),c=h,a=encodeURIComponent(",wl="+a+"/"+m),2E3>a.length+p?(2E3<k+a.length&&u(),void 0===g[c]&&(g[c]="",f.push(c)),g[c]+=a,k+=a.length,n||(n=e.setTimeout(u,E))):b.ue_int&&console.error("Invalid API call. The input provided is over 2000 chars.")):d.count&&(d.count("WeblabTriggerImproperAPICall",1),b.ue_int&&console.error("Invalid API call. The input provided does not match the API protocol i.e ue.trigger(String, String, Object)."))}}function F(){d.trigger&&
# d.trigger.isStub&&d.trigger.replay(function(a){v.apply(this,a)})}function y(){z||(f.length&&l(q),z=!0)}var t=":1234",s="//"+b.ue_furl+"/1/remote-weblab-triggers/1/OE/"+b.ue_mid+":"+b.ue_sid+":PLCHLDR_RID$s:wl-client-id%3DCSMTriger",A="PLCHLDR_RID",E=b.wtt||1E4,p=s.length+t.length,w=b.mwtc||2E3,G=1===e.ue_wtc_c,B=3===e.ue_wtc_c,H=e.XMLHttpRequest&&"withCredentials"in new e.XMLHttpRequest,x="String",D="Object",d=b.ue,g={},f=[],k=p,n,z=!1,r=0,C=function(){return{send:function(a){if(H){var b=new e.XMLHttpRequest;
# b.open("GET",a,!0);G&&(b.withCredentials=!0);b.send()}else throw"";}}}(),q=function(){return{send:function(a){(new Image).src=a}}}();e.encodeURIComponent&&(d.attach&&(d.attach("beforeunload",y),d.attach("pagehide",y)),F(),d.trigger=v)},"client-wbl-trg")(ue_csm,window);
#
#
# (function(k,d,h){function f(a,c,b){a&&a.indexOf&&0===a.indexOf("http")&&0!==a.indexOf("https")&&l(s,c,a,b)}function g(a,c,b){a&&a.indexOf&&(location.href.split("#")[0]!=a&&null!==a&&"undefined"!==typeof a||l(t,c,a,b))}function l(a,c,b,e){m[b]||(e=u&&e?n(e):"N/A",d.ueLogError&&d.ueLogError({message:a+c+" : "+b,logLevel:v,stack:"N/A"},{attribution:e}),m[b]=1,p++)}function e(a,c){if(a&&c)for(var b=0;b<a.length;b++)try{c(a[b])}catch(d){}}function q(){return d.performance&&d.performance.getEntriesByType?
# d.performance.getEntriesByType("resource"):[]}function n(a){if(a.id)return"//*[@id='"+a.id+"']";var c;c=1;var b;for(b=a.previousSibling;b;b=b.previousSibling)b.nodeName==a.nodeName&&(c+=1);b=a.nodeName;1!=c&&(b+="["+c+"]");a.parentNode&&(b=n(a.parentNode)+"/"+b);return b}function w(){var a=h.images;a&&a.length&&e(a,function(a){var b=a.getAttribute("src");f(b,"img",a);g(b,"img",a)})}function x(){var a=h.scripts;a&&a.length&&e(a,function(a){var b=a.getAttribute("src");f(b,"script",a);g(b,"script",a)})}
# function y(){var a=h.styleSheets;a&&a.length&&e(a,function(a){if(a=a.ownerNode){var b=a.getAttribute("href");f(b,"style",a);g(b,"style",a)}})}function z(){if(A){var a=q();e(a,function(a){f(a.name,a.initiatorType)})}}function B(){e(q(),function(a){g(a.name,a.initiatorType)})}function r(){var a;a=d.location&&d.location.protocol?d.location.protocol:void 0;"https:"==a&&(z(),w(),x(),y(),B(),p<C&&setTimeout(r,D))}var s="[CSM] Insecure content detected ",t="[CSM] Ajax request to same page detected ",v="WARN",
# m={},p=0,D=k.ue_nsip||1E3,C=5,A=1==k.ue_urt,u=!0;ue_csm.ue_disableNonSecure||(d.performance&&d.performance.setResourceTimingBufferSize&&d.performance.setResourceTimingBufferSize(300),r())})(ue_csm,window,document);
#
#
# var ue_aa_a = "";
# if (ue.trigger && (ue_aa_a === "C" || ue_aa_a === "T1")) {
#     ue.trigger("UEDATA_AA_SERVERSIDE_ASSIGNMENT_CLIENTSIDE_TRIGGER_190249", ue_aa_a);
# }
# (function(f,b){function g(){try{b.PerformanceObserver&&"function"===typeof b.PerformanceObserver&&(a=new b.PerformanceObserver(function(b){c(b.getEntries())}),a.observe(d))}catch(h){k()}}function m(){for(var h=d.entryTypes,a=0;a<h.length;a++)c(b.performance.getEntriesByType(h[a]))}function c(a){if(a&&Array.isArray(a)){for(var c=0,e=0;e<a.length;e++){var d=l.indexOf(a[e].name);if(-1!==d){var g=Math.round(b.performance.timing.navigationStart+a[e].startTime);f.uet(n[d],void 0,void 0,g);c++}}l.length===
# c&&k()}}function k(){a&&a.disconnect&&"function"===typeof a.disconnect&&a.disconnect()}if("function"===typeof f.uet&&b.performance&&"object"===typeof b.performance&&b.performance.getEntriesByType&&"function"===typeof b.performance.getEntriesByType&&b.performance.timing&&"object"===typeof b.performance.timing&&"number"===typeof b.performance.timing.navigationStart){var d={entryTypes:["paint"]},l=["first-paint","first-contentful-paint"],n=["fp","fcp"],a;try{m(),g()}catch(p){f.ueLogError(p,{logLevel:"ERROR",
# attribution:"performanceMetrics"})}}})(ue_csm,window);
#
#
# if (window.csa) {
#     csa("Events")("setEntity", {
#         page:{pageType: "chart", subPageType: "top250movie", pageTypeId: ""}
#     });
# }
# csa.plugin(function(c){var m="transitionStart",n="pageVisible",e="PageTiming",t="visibilitychange",s="$latency.visible",i=c.global,r=(i.performance||{}).timing,a=["navigationStart","unloadEventStart","unloadEventEnd","redirectStart","redirectEnd","fetchStart","domainLookupStart","domainLookupEnd","connectStart","connectEnd","secureConnectionStart","requestStart","responseStart","responseEnd","domLoading","domInteractive","domContentLoadedEventStart","domContentLoadedEventEnd","domComplete","loadEventStart","loadEventEnd"],u=c.config,o=i.Math,l=o.max,g=o.floor,d=i.document||{},f=(r||{}).navigationStart,v=f,p=0,S=null;if(i.Object.keys&&[].forEach&&!u["KillSwitch."+e]){if(!r||null===f||f<=0||void 0===f)return c.error("Invalid navigation timing data: "+f);S=new E({schemaId:"<ns>.PageLatency.6",producerId:"csa"}),"boolean"!=typeof d.hidden&&"string"!=typeof d.visibilityState||!d.removeEventListener?c.emit(s):b()?(c.emit(s),I(n,f)):c.on(d,t,function e(){b()&&(v=c.time(),d.removeEventListener(t,e),I(m,v),I(n,v),c.emit(s))}),c.once("$unload",h),c.once("$load",h),c.on("$pageTransition",function(){v=c.time()}),c.register(e,{mark:I,instance:function(e){return new E(e)}})}function E(e){var i,r=null,a=e.ent||{page:["pageType","subPageType","requestId"]},o=e.logger||c("Events",{producerId:e.producerId,lob:u.lob||"0"});if(!e||!e.producerId||!e.schemaId)return c.error("The producer id and schema Id must be defined for PageLatencyInstance.");function d(){return i||v}function n(){r=c.UUID()}this.mark=function(n,t){if(null!=n)return t=t||c.time(),n===m&&(i=t),c.once(s,function(){o("log",{messageId:r,__merge:function(e){e.markers[n]=function(e,n){return l(0,n-(e||v))}(d(),t),e.markerTimestamps[n]=g(t)},markers:{},markerTimestamps:{},navigationStartTimestamp:d()?new Date(d()).toISOString():null,schemaId:e.schemaId},{ent:a})}),t},n(),c.on("$beforePageTransition",n)}function I(e,n){e===m&&(v=n);var t=S.mark(e,n);c.emit("$timing:"+e,t)}function h(){if(!p){for(var e=0;e<a.length;e++)r[a[e]]&&I(a[e],r[a[e]]);p=1}}function b(){return!d.hidden||"visible"===d.visibilityState}});csa.plugin(function(u){var f,c,l="length",a="parentElement",t="target",i="getEntriesByName",e="perf",n=null,r="_csa_flt",o="_csa_llt",s="previousSibling",d="visuallyLoaded",g="client",h="offset",m="scroll",p="Width",v="Height",y=g+p,E=g+v,S=h+p,b=h+v,x=m+p,O=m+v,_="_osrc",w="_elt",L="_eid",T=10,I=5,N=15,k=100,B=u.global,H=u.timeout,W=B.Math,Y=W.max,C=W.floor,F=W.ceil,M=B.document||{},R=M.body||{},V=M.documentElement||{},$=B.performance||{},P=($.timing||{}).navigationStart,X=Date.now,D=Object.values||(u.types||{}).ovl,J=u("PageTiming"),j=u("SpeedIndexBuffers"),q=[],Q=[],U=[],z=[],A=[],G=[],K=.1,Z=.1,ee=0,ne=0,te=!0,ie=0,re=0,oe=1==u.config["SpeedIndex.ForceReplay"],ae=0,fe=1,ue=0,ce={},le=[],se=0,de={buffered:1};function ge(e){u.global.ue_csa_ss_tag||u.emit("$csmTag:"+e,0,de)}function he(){for(var e=X(),n=0;f;){if(0!==f[l]){if(!1!==f.h(f[0])&&f.shift(),n++,!oe&&n%T==0&&X()-e>I)break}else f=f.n}ee=0,f&&(ee||(!0===M.hidden?(oe=1,he()):u.timeout(he,0)))}function me(e,n,t,i,r){ue=C(e),q=n,Q=t,U=i,G=r;var o=M.createTreeWalker(M.body,NodeFilter.SHOW_TEXT,null,null),a={w:B.innerWidth,h:B.innerHeight,x:B.pageXOffset,y:B.pageYOffset};M.body[w]=e,z.push({w:o,vp:a}),A.push({img:M.images,iter:0}),q.h=pe,(q.n=Q).h=ve,(Q.n=U).h=ye,(U.n=z).h=Ee,(z.n=A).h=Se,(A.n=G).h=be,f=q,he()}function pe(e){e.m.forEach(function(e){for(var n=e;n&&(e===n||!n[r]||!n[o]);)n[r]||(n[r]=e[r]),n[o]||(n[o]=e[o]),n[w]=n[r]-P,n=n[s]})}function ve(e){e.m.forEach(function(e){var n=e[t];_ in n||(n[_]=e.oldValue)})}function ye(n){n.m.forEach(function(e){e[t][w]=n.t-P})}function Ee(e){for(var n,t=e.vp,i=e.w,r=T;(n=i.nextNode())&&0<r;){r-=1;var o=(n[a]||{}).nodeName;"SCRIPT"!==o&&"STYLE"!==o&&"NOSCRIPT"!==o&&"BODY"!==o&&0!==(n.nodeValue||"").trim()[l]&&Le(n[a],xe(n),t)}return!n}function Se(e){for(var n={w:B.innerWidth,h:B.innerHeight,x:B.pageXOffset,y:B.pageYOffset},t=T;e.iter<e.img[l]&&0<t;){var i,r=e.img[e.iter],o=we(r),a=o&& ...
#
#
# ue.exec(function(d,c){function g(e,c){e&&ue.tag(e+c);return!!e}function n(){for(var e=RegExp("^https://(.*\.(images|ssl-images|media)-amazon\.com|"+c.location.hostname+")/images/","i"),d={},h=0,k=c.performance.getEntriesByType("resource"),l=!1,b,a,m,f=0;f<k.length;f++)if(a=k[f],0<a.transferSize&&a.transferSize>=a.encodedBodySize&&(b=e.exec(String(a.name)))&&3===b.length){a:{b=a.serverTiming||[];for(a=0;a<b.length;a++)if("provider"===b[a].name){b=b[a].description;break a}b=void 0}b&&(l||(l=g(b,"_cdn_fr")),
# a=d[b]=(d[b]||0)+1,a>h&&(m=b,h=a))}g(m,"_cdn_mp")}d.ue&&"function"===typeof d.ue.tag&&c.performance&&c.location&&n()},"cdnTagging")(ue_csm,window);
#
#
# }
#
# /* ◬ */
#     </script>
#    </div>
#    <noscript>
#     <img alt="" height="1" src="//fls-na.amazon.com/1/batch/1/OP/A1EVAM02EL8SFB:137-3713988-0011656:RGRS4XPFBK3JY7C1RV7P$uedata=s:%2Fuedata%2Fuedata%3Fnoscript%26id%3DRGRS4XPFBK3JY7C1RV7P:0" style="display:none;visibility:hidden;" width="1">
#     </img>
#    </noscript>
#    <script>
#     window.ue && ue.count && ue.count('CSMLibrarySize', 60245)
#    </script>
#   </div>
#   <next-route-announcer>
#    <p aria-live="assertive" id="__next-route-announcer__" role="alert" style="border: 0px; clip: rect(0px, 0px, 0px, 0px); height: 1px; margin: -1px; overflow: hidden; padding: 0px; position: absolute; width: 1px; white-space: nowrap; overflow-wrap: normal;">
#    </p>
#   </next-route-announcer>
#  </body>
# </html>
#
# 250

# %% [markdown]
# ### Primary data

# %%
containers = BeautifulSoup(content, "html.parser")
filename= "./data/imdb_primary_uas.csv"
f= open(filename, "w")
headers= "Name,Year,Durasi(Menit),Rating,Rated\n"
f.write(headers)

# print(containers.prettify())

movies = containers.find_all("div", {"class": "sc-b189961a-0 hBZnfJ cli-children"})
# movies = containers.find_all("div", {"class": "top-picks-title"})

print("movies: ", len(movies))
for movie in movies:
    year = ""
    durasi_menit = ""
    rated = "None"
    name = ""
    name = re.sub(r"\d+. ","", movie.find("h3", {"class": "ipc-title__text"}).text)
    name = re.sub(r',', ':', name)
    metadata = movie.find_all("span", {"class": "sc-b189961a-8 kLaxqf cli-title-metadata-item"})

    if len(metadata) > 2:
        year = metadata[0].text
        durasi = metadata[1].text
        durasi = durasi.split(" ")
        if len(durasi) > 1:
            durasi_menit = int(durasi[0].replace("h",""))*60 + int(durasi[1].replace("m",""))
        rated = metadata[2].text
    elif len(metadata) > 1:
        year = metadata[0].text
        durasi = metadata[1].text
        durasi = durasi.split(" ")
        if len(durasi) > 1:
            durasi_menit = int(durasi[0].replace("h",""))*60 + int(durasi[1].replace("m",""))
        else:
            durasi_menit = int(durasi[0].replace("h",""))*60
        rated = "None"
    else:
        year = metadata[0].text
        durasi_menit = 0
        rated = "None"
    rating_element = soup.find('span', class_='ipc-rating-star ipc-rating-star--base ipc-rating-star--imdb ratingGroup--imdb-rating')
    rating = rating_element.contents[1].strip()

    print(name, ",", year, ",", durasi_menit, ",", rating, ",", rated)
    f.write(name + "," + str(year) + "," + str(durasi_menit) + "," + rating + "," + rated + "\n")
# Out:
# movies:  250
# The Shawshank Redemption , 1994 , 142 , 9.3 , 15
# The Godfather , 1972 , 175 , 9.3 , 15
# The Dark Knight , 2008 , 152 , 9.3 , 12A
# The Godfather Part II , 1974 , 202 , 9.3 , X
# Angry Men , 1957 , 96 , 9.3 , U
# Schindler's List , 1993 , 195 , 9.3 , 15
# The Lord of the Rings: The Return of the King , 2003 , 201 , 9.3 , 12A
# Pulp Fiction , 1994 , 154 , 9.3 , 18
# The Lord of the Rings: The Fellowship of the Ring , 2001 , 178 , 9.3 , PG
# The Good: the Bad and the Ugly , 1966 , 148 , 9.3 , 18
# Forrest Gump , 1994 , 142 , 9.3 , 12
# The Lord of the Rings: The Two Towers , 2002 , 179 , 9.3 , 12A
# Fight Club , 1999 , 139 , 9.3 , 15
# Inception , 2010 , 148 , 9.3 , 12A
# Star Wars: Episode V - The Empire Strikes Back , 1980 , 124 , 9.3 , U
# The Matrix , 1999 , 136 , 9.3 , 15
# GoodFellas , 1990 , 145 , 9.3 , 18
# One Flew Over the Cuckoo's Nest , 1975 , 133 , 9.3 , 15
# Seven , 1995 , 127 , 9.3 , 18
# Interstellar , 2014 , 169 , 9.3 , 12A
# It's a Wonderful Life , 1946 , 130 , 9.3 , U
# Seven Samurai , 1954 , 207 , 9.3 , PG
# The Silence of the Lambs , 1991 , 118 , 9.3 , 18
# Saving Private Ryan , 1998 , 169 , 9.3 , 15
# City of God , 2002 , 130 , 9.3 , 18
# Life Is Beautiful , 1997 , 116 , 9.3 , PG
# The Green Mile , 1999 , 189 , 9.3 , 18
# Terminator Judgment Day , 1991 , 137 , 9.3 , 15
# Star Wars: Episode IV - A New Hope , 1977 , 121 , 9.3 , U
# Dune: Part Two , 2024 , 166 , 9.3 , 12A
# Back to the Future , 1985 , 116 , 9.3 , PG
# Spirited Away , 2001 , 125 , 9.3 , PG
# The Pianist , 2002 , 150 , 9.3 , 15
# Parasite , 2019 , 132 , 9.3 , 15
# Psycho , 1960 , 109 , 9.3 , 15
# Gladiator , 2000 , 155 , 9.3 , 15
# Spider-Man: Across the Spider-Verse , 2023 , 140 , 9.3 , PG
# The Lion King , 1994 , 88 , 9.3 , U
# The Departed , 2006 , 151 , 9.3 , 18
# Leon , 1994 , 110 , 9.3 , 18
# American History X , 1998 , 119 , 9.3 , 18
# Whiplash , 2014 , 106 , 9.3 , 15
# The Prestige , 2006 , 130 , 9.3 , 12A
# Grave of the Fireflies , 1988 , 89 , 9.3 , 12A
# Harakiri , 1962 , 133 , 9.3 , X
# The Usual Suspects , 1995 , 106 , 9.3 , 18
# Casablanca , 1942 , 102 , 9.3 , U
# Untouchable , 2011 , 112 , 9.3 , 15
# Cinema Paradiso , 1988 , 174 , 9.3 , PG
# Modern Times , 1936 , 87 , 9.3 , U
# Rear Window , 1954 , 112 , 9.3 , PG
# Once Upon a Time in the West , 1968 , 166 , 9.3 , 12
# Alien , 1979 , 117 , 9.3 , X
# City Lights , 1931 , 87 , 9.3 , U
# Django Unchained , 2012 , 165 , 9.3 , 18
# Apocalypse Now , 1979 , 147 , 9.3 , X
# Memento , 2000 , 113 , 9.3 , 15
# WALL·E , 2008 , 98 , 9.3 , U
# 12th Fail , 2023 , 147 , 9.3 , 12A
# Raiders of the Lost Ark , 1981 , 115 , 9.3 , PG
# The Lives of Others , 2006 , 137 , 9.3 , 15
# Sunset Blvd. , 1950 , 110 , 9.3 , PG
# Avengers: Infinity War , 2018 , 149 , 9.3 , 12A
# Paths of Glory , 1957 , 88 , 9.3 , PG
# Spider-Man: Into the Spider-Verse , 2018 , 117 , 9.3 , PG
# Witness for the Prosecution , 1957 , 116 , 9.3 , U
# The Shining , 1980 , 146 , 9.3 , X
# The Great Dictator , 1940 , 125 , 9.3 , PG
# Aliens , 1986 , 137 , 9.3 , 18
# Inglourious Basterds , 2009 , 153 , 9.3 , 18
# The Dark Knight Rises , 2012 , 164 , 9.3 , 12A
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb , 1964 , 95 , 9.3 , PG
# Coco , 2017 , 105 , 9.3 , PG
# Oldboy , 2003 ,  , 9.3 , 18
# American Beauty , 1999 , 122 , 9.3 , 18
# Amadeus , 1984 , 160 , 9.3 , PG
# Toy Story , 1995 , 81 , 9.3 , PG
# Avengers: Endgame , 2019 , 181 , 9.3 , 12A
# Das Boot , 1981 , 149 , 9.3 , AA
# Braveheart , 1995 , 178 , 9.3 , 15
# Good Will Hunting , 1997 , 126 , 9.3 , 15
# Princess Mononoke , 1997 , 134 , 9.3 , PG
# Joker , 2019 , 122 , 9.3 , 15
# Your Name. , 2016 , 106 , 9.3 , 12A
# High and Low , 1963 , 143 , 9.3 , 12
# Once Upon a Time in America , 1984 , 229 , 9.3 , 18
# 3 Idiots , 2009 , 170 , 9.3 , 12A
# Singin' in the Rain , 1952 , 103 , 9.3 , U
# Capernaum , 2018 , 126 , 9.3 , 15
# Come and See , 1985 , 142 , 9.3 , 15
# Requiem for a Dream , 2000 , 102 , 9.3 , 18
# Toy Story 3 , 2010 , 103 , 9.3 , PG
# Star Wars: Episode VI - Return of the Jedi , 1983 , 131 , 9.3 , PG
# Eternal Sunshine of the Spotless Mind , 2004 , 108 , 9.3 , 15
# The Hunt , 2012 , 115 , 9.3 , 15
# A Space Odyssey , 1968 , 149 , 9.3 , U
# Reservoir Dogs , 1992 , 99 , 9.3 , 18
# Ikiru , 1952 , 143 , 9.3 , PG
# Oppenheimer , 2023 ,  , 9.3 , 15
# Lawrence of Arabia , 1962 , 218 , 9.3 , PG
# The Apartment , 1960 , 125 , 9.3 , PG
# Incendies , 2010 , 131 , 9.3 , 15
# North by Northwest , 1959 , 136 , 9.3 , PG
# Citizen Kane , 1941 , 119 , 9.3 , A
# M , 1931 , 117 , 9.3 , PG
# Scarface , 1983 , 170 , 9.3 , 18
# Double Indemnity , 1944 , 107 , 9.3 , A
# Vertigo , 1958 , 128 , 9.3 , PG
# Full Metal Jacket , 1987 , 116 , 9.3 , 18
# Amélie , 2001 , 122 , 9.3 , 15
# Heat , 1995 , 170 , 9.3 , 15
# Up , 2009 , 96 , 9.3 , U
# A Clockwork Orange , 1971 , 136 , 9.3 , X
# To Kill a Mockingbird , 1962 , 129 , 9.3 , PG
# A Separation , 2011 , 123 , 9.3 , PG
# The Sting , 1973 , 129 , 9.3 , PG
# Indiana Jones and the Last Crusade , 1989 , 127 , 9.3 , PG
# Die Hard , 1988 , 132 , 9.3 , 18
# Like Stars on Earth , 2007 , 162 , 9.3 , PG
# Metropolis , 1927 , 153 , 9.3 , PG
# Snatch , 2000 , 104 , 9.3 , 18
# L.A. Confidential , 1997 , 138 , 9.3 , 18
# 1917 , 2019 , 119 , 9.3 , 15
# Hamilton , 2020 , 160 , 9.3 , 12
# Bicycle Thieves , 1948 , 89 , 9.3 , U
# Taxi Driver , 1976 , 114 , 9.3 , 18
# Downfall , 2004 , 156 , 9.3 , 15
# Dangal , 2016 , 161 , 9.3 , PG
# For a Few Dollars More , 1965 , 132 , 9.3 , 15
# Batman Begins , 2005 , 140 , 9.3 , 12A
# The Wolf of Wall Street , 2013 ,  , 9.3 , 18
# Some Like It Hot , 1959 , 121 , 9.3 , A
# Green Book , 2018 , 130 , 9.3 , 12A
# The Kid , 1921 , 68 , 9.3 , U
# The Father , 2020 , 97 , 9.3 , 12A
# Judgment at Nuremberg , 1961 , 179 , 9.3 , PG
# The Truman Show , 1998 , 103 , 9.3 , PG
# All About Eve , 1950 , 138 , 9.3 , PG
# Shutter Island , 2010 , 138 , 9.3 , 15
# Top Gun: Maverick , 2022 , 130 , 9.3 , 12A
# There Will Be Blood , 2007 , 158 , 9.3 , 12A
# Casino , 1995 , 178 , 9.3 , 18
# Jurassic Park , 1993 , 127 , 9.3 , PG
# Ran , 1985 , 160 , 9.3 , 15
# The Sixth Sense , 1999 , 107 , 9.3 , 15
# Pan's Labyrinth , 2006 , 118 , 9.3 , 15
# Unforgiven , 1992 , 130 , 9.3 , 15
# No Country for Old Men , 2007 , 122 , 9.3 , 15
# A Beautiful Mind , 2001 , 135 , 9.3 , 12
# The Thing , 1982 , 109 , 9.3 , X
# Kill Bill: Vol. 1 , 2003 , 111 , 9.3 , 18
# The Treasure of the Sierra Madre , 1948 , 126 , 9.3 , PG
# Yojimbo , 1961 , 110 , 9.3 , PG
# Monty Python and the Holy Grail , 1975 , 91 , 9.3 , 12A
# The Great Escape , 1963 , 172 , 9.3 , PG
# Finding Nemo , 2003 , 100 , 9.3 , U
# Prisoners , 2013 , 153 , 9.3 , 15
# Howl's Moving Castle , 2004 , 119 , 9.3 , U
# Rashomon , 1950 , 88 , 9.3 , X
# The Elephant Man , 1980 , 124 , 9.3 , PG
# Dial M for Murder , 1954 , 105 , 9.3 , PG
# Chinatown , 1974 , 130 , 9.3 , X
# Gone with the Wind , 1939 , 238 , 9.3 , PG
# Lock: Stock and Two Smoking Barrels , 1998 , 107 , 9.3 , 18
# The Secret in Their Eyes , 2009 , 129 , 9.3 , 18
# V for Vendetta , 2005 , 132 , 9.3 , 15
# Inside Out , 2015 , 95 , 9.3 , U
# Raging Bull , 1980 , 129 , 9.3 , X
# Three Billboards Outside Ebbing: Missouri , 2017 , 115 , 9.3 , 15
# Trainspotting , 1996 , 93 , 9.3 , 18
# The Bridge on the River Kwai , 1957 , 161 , 9.3 , PG
# Klaus , 2019 , 96 , 9.3 , PG
# Fargo , 1996 , 98 , 9.3 , 18
# Catch Me If You Can , 2002 , 141 , 9.3 , 12A
# Spider-Man: No Way Home , 2021 , 148 , 9.3 , 12A
# Warrior , 2011 , 140 , 9.3 , 12A
# Gran Torino , 2008 , 116 , 9.3 , 15
# Million Dollar Baby , 2004 , 132 , 9.3 , 12A
# Harry Potter and the Deathly Hallows: Part 2 , 2011 , 130 , 9.3 , 12A
# My Neighbour Totoro , 1988 , 86 , 9.3 , U
# Children of Heaven , 1997 , 89 , 9.3 , PG
# Years a Slave , 2013 , 134 , 9.3 , 15
# Ben-Hur , 1959 , 212 , 9.3 , PG
# Blade Runner , 1982 , 117 , 9.3 , AA
# Before Sunrise , 1995 , 101 , 9.3 , 15
# The Grand Budapest Hotel , 2014 , 99 , 9.3 , 15
# Barry Lyndon , 1975 , 185 , 9.3 , PG
# Mad Max: Fury Road , 2015 ,  , 9.3 , 15
# Gone Girl , 2014 , 149 , 9.3 , 18
# Hacksaw Ridge , 2016 , 139 , 9.3 , 15
# The Gold Rush , 1925 , 95 , 9.3 , U
# Dead Poets Society , 1989 , 128 , 9.3 , PG
# Memories of Murder , 2003 , 131 , 9.3 , 15
# In the Name of the Father , 1993 , 133 , 9.3 , 15
# Wild Tales , 2014 , 122 , 9.3 , 15
# The Deer Hunter , 1978 , 183 , 9.3 , X
# Monsters: Inc. , 2001 , 92 , 9.3 , U
# The General , 1926 , 78 , 9.3 , U
# On the Waterfront , 1954 , 108 , 9.3 , PG
# Sherlock Jr. , 1924 ,  , 9.3 , U
# How to Train Your Dragon , 2010 , 98 , 9.3 , PG
# Jaws , 1975 , 124 , 9.3 , PG
# The Third Man , 1949 , 104 , 9.3 , PG
# The Wages of Fear , 1953 , 131 , 9.3 , PG
# Mary and Max , 2009 , 92 , 9.3 , 12A
# Wild Strawberries , 1957 , 91 , 9.3 , PG
# Ratatouille , 2007 , 111 , 9.3 , PG
# Mr. Smith Goes to Washington , 1939 , 129 , 9.3 , U
# Le Mans '66 , 2019 , 152 , 9.3 , 12A
# Tokyo Story , 1953 , 136 , 9.3 , U
# The Big Lebowski , 1998 , 117 , 9.3 , 18
# Room , 2015 , 118 , 9.3 , 15
# Rocky , 1976 ,  , 9.3 , PG
# The Seventh Seal , 1957 , 96 , 9.3 , PG
# Logan , 2017 , 137 , 9.3 , 15
# Spotlight , 2015 , 129 , 9.3 , 15
# Hotel Rwanda , 2004 , 121 , 9.3 , 12A
# The Terminator , 1984 , 107 , 9.3 , 18
# Platoon , 1986 ,  , 9.3 , 15
# La haine , 1995 , 98 , 9.3 , 15
# The Passion of Joan of Arc , 1928 , 110 , 9.3 , PG
# Before Sunset , 2004 , 80 , 9.3 , 15
# The Best Years of Our Lives , 1946 , 170 , 9.3 , U
# Pirates of the Caribbean: The Curse of the Black Pearl , 2003 , 143 , 9.3 , 12A
# The Exorcist , 1973 , 122 , 9.3 , X
# Jai Bhim , 2021 , 164 , 9.3 , Not Rated
# Rush , 2013 , 123 , 9.3 , 15
# Network , 1976 , 121 , 9.3 , AA
# The Wizard of Oz , 1939 , 102 , 9.3 , A
# Stand by Me , 1986 , 89 , 9.3 , 15
# The Incredibles , 2004 , 115 , 9.3 , U
# Hachi: A Dog's Tale , 2009 , 93 , 9.3 , U
# My Father and My Son , 2005 , 112 , 9.3 , PG
# The Handmaiden , 2016 , 145 , 9.3 , 18
# The Sound of Music , 1965 , 172 , 9.3 , U
# Into the Wild , 2007 , 148 , 9.3 , 15
# To Be or Not to Be , 1942 , 99 , 9.3 , U
# The Battle of Algiers , 1966 , 121 , 9.3 , X
# The Grapes of Wrath , 1940 , 129 , 9.3 , PG
# Groundhog Day , 1993 , 101 , 9.3 , PG
# Amores perros , 2000 , 154 , 9.3 , 18
# The Iron Giant , 1999 , 86 , 9.3 , PG
# Rebecca , 1940 , 130 , 9.3 , PG
# Cool Hand Luke , 1967 , 127 , 9.3 , A
# The Help , 2011 , 146 , 9.3 , 12A
# It Happened One Night , 1934 , 105 , 9.3 , A
# Drishyam , 2015 , 163 , 9.3 , 12A
# Dances with Wolves , 1990 , 181 , 9.3 , PG
# Aladdin , 1992 , 90 , 9.3 , U
# Gangs of Wasseypur , 2012 , 321 , 9.3 , 18

# %%
links = browser.find_elements(By.XPATH, '//div[@class="sc-b189961a-0 hBZnfJ"]')
movie_titles = browser.find_elements(By.XPATH, '//h3[@class="ipc-title__text"]')
print(movie_titles)
count = 0
for link in links:
    title = re.sub(r"\d+. ","", movie_titles[link].text)
    print("judul ke-" + str(link+1) + ": " + title)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.4852")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9229")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9235")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9241")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9247")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9253")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9259")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9265")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9271")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9277")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9283")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9289")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9295")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9301")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9307")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9313")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9319")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9325")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9331")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9337")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF228.d.15E5E43B3AC9EC668EB63DF0F632F7DF.e.9343")>, <selenium.webdriver.remote.webelement.WebElement (session="eb520d0f70c4fc1a0ca11c2daadf8fc3", element="f.112EF0FDD0FAC11CE6ED1470742DF2 ...

# %% [markdown]
# ### Secondary Data

# %% [markdown]
# #### simpan dulu ke file.txt

# %%
browser2 = Chrome(options=chrome_options, service = service)
movies_2 = containers.find_all("div", {"class": "sc-b189961a-0 hBZnfJ cli-children"})
base_link = 'https://www.imdb.com'
with open('./data/list_link.txt', 'w') as f:
    for movie in movies_2:
        link = movie.find('a').get('href')
        link = base_link + link
        print(link)
        f.write(link + '\n')
# Out:
# https://www.imdb.com/title/tt0111161/?ref_=chttp_t_1
# https://www.imdb.com/title/tt0068646/?ref_=chttp_t_2
# https://www.imdb.com/title/tt0468569/?ref_=chttp_t_3
# https://www.imdb.com/title/tt0071562/?ref_=chttp_t_4
# https://www.imdb.com/title/tt0050083/?ref_=chttp_t_5
# https://www.imdb.com/title/tt0108052/?ref_=chttp_t_6
# https://www.imdb.com/title/tt0167260/?ref_=chttp_t_7
# https://www.imdb.com/title/tt0110912/?ref_=chttp_t_8
# https://www.imdb.com/title/tt0120737/?ref_=chttp_t_9
# https://www.imdb.com/title/tt0060196/?ref_=chttp_t_10
# https://www.imdb.com/title/tt0109830/?ref_=chttp_t_11
# https://www.imdb.com/title/tt0167261/?ref_=chttp_t_12
# https://www.imdb.com/title/tt0137523/?ref_=chttp_t_13
# https://www.imdb.com/title/tt1375666/?ref_=chttp_t_14
# https://www.imdb.com/title/tt0080684/?ref_=chttp_t_15
# https://www.imdb.com/title/tt0133093/?ref_=chttp_t_16
# https://www.imdb.com/title/tt0099685/?ref_=chttp_t_17
# https://www.imdb.com/title/tt0073486/?ref_=chttp_t_18
# https://www.imdb.com/title/tt0114369/?ref_=chttp_t_19
# https://www.imdb.com/title/tt0816692/?ref_=chttp_t_20
# https://www.imdb.com/title/tt0038650/?ref_=chttp_t_21
# https://www.imdb.com/title/tt0047478/?ref_=chttp_t_22
# https://www.imdb.com/title/tt0102926/?ref_=chttp_t_23
# https://www.imdb.com/title/tt0120815/?ref_=chttp_t_24
# https://www.imdb.com/title/tt0317248/?ref_=chttp_t_25
# https://www.imdb.com/title/tt0118799/?ref_=chttp_t_26
# https://www.imdb.com/title/tt0120689/?ref_=chttp_t_27
# https://www.imdb.com/title/tt0103064/?ref_=chttp_t_28
# https://www.imdb.com/title/tt0076759/?ref_=chttp_t_29
# https://www.imdb.com/title/tt15239678/?ref_=chttp_t_30
# https://www.imdb.com/title/tt0088763/?ref_=chttp_t_31
# https://www.imdb.com/title/tt0245429/?ref_=chttp_t_32
# https://www.imdb.com/title/tt0253474/?ref_=chttp_t_33
# https://www.imdb.com/title/tt6751668/?ref_=chttp_t_34
# https://www.imdb.com/title/tt0054215/?ref_=chttp_t_35
# https://www.imdb.com/title/tt0172495/?ref_=chttp_t_36
# https://www.imdb.com/title/tt9362722/?ref_=chttp_t_37
# https://www.imdb.com/title/tt0110357/?ref_=chttp_t_38
# https://www.imdb.com/title/tt0407887/?ref_=chttp_t_39
# https://www.imdb.com/title/tt0110413/?ref_=chttp_t_40
# https://www.imdb.com/title/tt0120586/?ref_=chttp_t_41
# https://www.imdb.com/title/tt2582802/?ref_=chttp_t_42
# https://www.imdb.com/title/tt0482571/?ref_=chttp_t_43
# https://www.imdb.com/title/tt0095327/?ref_=chttp_t_44
# https://www.imdb.com/title/tt0056058/?ref_=chttp_t_45
# https://www.imdb.com/title/tt0114814/?ref_=chttp_t_46
# https://www.imdb.com/title/tt0034583/?ref_=chttp_t_47
# https://www.imdb.com/title/tt1675434/?ref_=chttp_t_48
# https://www.imdb.com/title/tt0095765/?ref_=chttp_t_49
# https://www.imdb.com/title/tt0027977/?ref_=chttp_t_50
# https://www.imdb.com/title/tt0047396/?ref_=chttp_t_51
# https://www.imdb.com/title/tt0064116/?ref_=chttp_t_52
# https://www.imdb.com/title/tt0078748/?ref_=chttp_t_53
# https://www.imdb.com/title/tt0021749/?ref_=chttp_t_54
# https://www.imdb.com/title/tt1853728/?ref_=chttp_t_55
# https://www.imdb.com/title/tt0078788/?ref_=chttp_t_56
# https://www.imdb.com/title/tt0209144/?ref_=chttp_t_57
# https://www.imdb.com/title/tt0910970/?ref_=chttp_t_58
# https://www.imdb.com/title/tt23849204/?ref_=chttp_t_59
# https://www.imdb.com/title/tt0082971/?ref_=chttp_t_60
# https://www.imdb.com/title/tt0405094/?ref_=chttp_t_61
# https://www.imdb.com/title/tt0043014/?ref_=chttp_t_62
# https://www.imdb.com/title/tt4154756/?ref_=chttp_t_63
# https://www.imdb.com/title/tt0050825/?ref_=chttp_t_64
# https://www.imdb.com/title/tt4633694/?ref_=chttp_t_65
# https://www.imdb.com/title/tt0051201/?ref_=chttp_t_66
# https://www.imdb.com/title/tt0081505/?ref_=chttp_t_67
# https://www.imdb.com/title/tt0032553/?ref_=chttp_t_68
# https://www.imdb.com/title/tt0090605/?ref_=chttp_t_69
# https://www.imdb.com/title/tt0361748/?ref_=chttp_t_70
# https://www.imdb.com/title/tt1345836/?ref_=chttp_t_71
# https://www.imdb.com/title/tt0057012/?ref_=chttp_t_72
# https://www.imdb.com/title/tt2380307/?ref_=chttp_t_73
# https://www.imdb.com/title/tt0364569/?ref_=chttp_t_74
# https://www.imdb.com/title/tt0169547/?ref_=chttp_t_75
# https://www.imdb.com/title/tt0086879/?ref_=chttp_t_76
# https://www.imdb.com/title/tt0114709/?ref_=chttp_t_77
# https://www.imdb.com/title/tt4154796/?ref_=chttp_t_78
# https://www.imdb.com/title/tt0082096/?ref_=chttp_t_79
# https://www.imdb.com/title/tt0112573/?ref_=chttp_t_80
# https://www.imdb.com/title/tt0119217/?ref_=chttp_t_81
# https://www.imdb.com/title/tt0119698/?ref_=chttp_t_82
# https://www.imdb.com/title/tt7286456/?ref_=chttp_t_83
# https://www.imdb.com/title/tt5311514/?ref_=chttp_t_84
# https://www.imdb.com/title/tt0057565/?ref_=chttp_t_85
# https://www.imdb.com/title/tt0087843/?ref_=chttp_t_86
# https://www.imdb.com/title/tt1187043/?ref_=chttp_t_87
# https://www.imdb.com/title/tt0045152/?ref_=chttp_t_88
# https://www.imdb.com/title/tt8267604/?ref_=chttp_t_89
# https://www.imdb.com/title/tt0091251/?ref_=chttp_t_90
# https://www.imdb.com/title/tt0180093/?ref_=chttp_t_91
# https://www.imdb.com/title/tt0435761/?ref_=chttp_t_92
# https://www.imdb.com/title/tt0086190/?ref_=chttp_t_93
# https://www.imdb.com/title/tt0338013/?ref_=chttp_t_94
# https://www.imdb.com/title/tt2106476/?ref_=chttp_t_95
# https://www.imdb.com/title/tt0062622/?ref_=chttp_t_96
# https://www.imdb.com/title/tt0105236/?ref_=chttp_t_97
# https://www.imdb.com/title/tt0044741/?ref_=chttp_t_98
# https://www.imdb.com/title/tt15398776/?ref_=chttp_t_99
# https://www.imdb.com/title/tt0056172/?ref_=chttp_t_100
# https://www.imdb.com/title/tt0053604/?ref_=chttp_t_101
# https://www.imdb.com/title/tt1255953/?ref_=chttp_t_102
# https://www.imdb.com/title/tt0053125/?ref_=chttp_t_103
# https://www.imdb.com/title/tt0033467/?ref_=chttp_t_104
# https://www.imdb.com/title/tt0022100/?ref_=chttp_t_105
# https://www.imdb.com/title/tt0086250/?ref_=chttp_t_106
# https://www.imdb.com/title/tt0036775/?ref_=chttp_t_107
# https://www.imdb.com/title/tt0052357/?ref_=chttp_t_108
# https://www.imdb.com/title/tt0093058/?ref_=chttp_t_109
# https://www.imdb.com/title/tt0211915/?ref_=chttp_t_110
# https://www.imdb.com/title/tt0113277/?ref_=chttp_t_111
# https://www.imdb.com/title/tt1049413/?ref_=chttp_t_112
# https://www.imdb.com/title/tt0066921/?ref_=chttp_t_113
# https://www.imdb.com/title/tt0056592/?ref_=chttp_t_114
# https://www.imdb.com/title/tt1832382/?ref_=chttp_t_115
# https://www.imdb.com/title/tt0070735/?ref_=chttp_t_116
# https://www.imdb.com/title/tt0097576/?ref_=chttp_t_117
# https://www.imdb.com/title/tt0095016/?ref_=chttp_t_118
# https://www.imdb.com/title/tt0986264/?ref_=chttp_t_119
# https://www.imdb.com/title/tt0017136/?ref_=chttp_t_120
# https://www.imdb.com/title/tt0208092/?ref_=chttp_t_121
# https://www.imdb.com/title/tt0119488/?ref_=chttp_t_122
# https://www.imdb.com/title/tt8579674/?ref_=chttp_t_123
# https://www.imdb.com/title/tt8503618/?ref_=chttp_t_124
# https://www.imdb.com/title/tt0040522/?ref_=chttp_t_125
# https://www.imdb.com/title/tt0075314/?ref_=chttp_t_126
# https://www.imdb.com/title/tt0363163/?ref_=chttp_t_127
# https://www.imdb.com/title/tt5074352/?ref_=chttp_t_128
# https://www.imdb.com/title/tt0059578/?ref_=chttp_t_129
# https://www.imdb.com/title/tt0372784/?ref_=chttp_t_130
# https://www.imdb.com/title/tt0993846/?ref_=chttp_t_131
# https://www.imdb.com/title/tt0053291/?ref_=chttp_t_132
# https://www.imdb.com/title/tt6966692/?ref_=chttp_t_133
# https://www.imdb.com/title/tt0012349/?ref_=chttp_t_134
# https://www.imdb.com/title/tt10272386/?ref_=chttp_t_135
# https://www.imdb.com/title/tt0055031/?ref_=chttp_t_136
# https://www.imdb.com/title/tt0120382/?ref_=chttp_t_137
# https://www.imdb.com/title/tt0042192/?ref_=chttp_t_138
# https://www.imdb.com/title/tt1130884/?ref_=chttp_t_139
# https://www.imdb.com/title/tt1745960/?ref_=chttp_t_140
# https://www.imdb.com/title/tt0469494/?ref_=chttp_t_141
# https://www.imdb.com/title/tt0112641/?ref_=chttp_t_142
# https://www.imdb.com/title/tt0107290/?ref_=chttp_t_143
# https://www.imdb.com/title/tt0089881/?ref_=chttp_t_144
# https://www.imdb.com/title/tt0167404/?ref_=chttp_t_145
# https://www.imdb.com/title/tt0457430/?ref_=chttp_t_146
# https://www.imdb.com/title/tt0105695/?ref_=chttp_t_147
# https://www.imdb.com/title/tt0477348/?ref_=chttp_t_148
# https://www.imdb.com/title/tt0268978/?ref_=chttp_t_149
# https://www.imdb.com/title/tt0084787/?ref_=chttp_t_150
# https://www.imdb.com/title/tt0266697/?ref_=chttp_t_151
# https://www.imdb.com/title/tt0040897/?ref_=chttp_t_152
# https://www.imdb.com/title/tt0055630/?ref_=chttp_t_153
# https://www.imdb.com/title/tt0071853/?ref_=chttp_t_154
# https://www.imdb.com/title/tt0057115/?ref_=chttp_t_155
# https://www.imdb.com/title/tt0266543/?ref_=chttp_t_156
# https://www.imdb.com/title/tt1392214/?ref_=chttp_t_157
# https://www.imdb.com/title/tt0347149/?ref_=chttp_t_158
# https://www.imdb.com/title/tt0042876/?ref_=chttp_t_159
# https://www.imdb.com/title/tt0080678/?ref_=chttp_t_160
# https://www.imdb.com/title/tt0046912/?ref_=chttp_t_161
# https://www.imdb.com/title/tt0071315/?ref_=chttp_t_162
# https://www.imdb.com/title/tt0031381/?ref_=chttp_t_163
# https://www.imdb.com/title/tt0120735/?ref_=chttp_t_164
# https://www.imdb.com/title/tt1305806/?ref_=chttp_t_165
# https://www.imdb.com/title/tt0434409/?ref_=chttp_t_166
# https://www.imdb.com/title/tt2096673/?ref_=chttp_t_167
# https://www.imdb.com/title/tt0081398/?ref_=chttp_t_168
# https://www.imdb.com/title/tt5027774/?ref_=chttp_t_169
# https://www.imdb.com/title/tt0117951/?ref_=chttp_t_170
# https://www.imdb.com/title/tt0050212/?ref_=chttp_t_171
# https://www.imdb.com/title/tt4729430/?ref_=chttp_t_172
# https://www.imdb.com/title/tt0116282/?ref_=chttp_t_173
# https://www.imdb.com/title/tt0264464/?ref_=chttp_t_174
# https://www.imdb.com/title/tt10872600/?ref_=chttp_t_175
# https://www.imdb.com/title/tt1291584/?ref_=chttp_t_176
# https://www.imdb.com/title/tt1205489/?ref_=chttp_t_177
# https://www.imdb.com/title/tt0405159/?ref_=chttp_t_178
# https://www.imdb.com/title/tt1201607/?ref_=chttp_t_179
# https://www.imdb.com/title/tt0096283/?ref_=chttp_t_180
# https://www.imdb.com/title/tt0118849/?ref_=chttp_t_181
# https://www.imdb.com/title/tt2024544/?ref_=chttp_t_182
# https://www.imdb.com/title/tt0052618/?ref_=chttp_t_183
# https://www.imdb.com/title/tt0083658/?ref_=chttp_t_184
# https://www.imdb.com/title/tt0112471/?ref_=chttp_t_185
# https://www.imdb.com/title/tt2278388/?ref_=chttp_t_186
# https://www.imdb.com/title/tt0072684/?ref_=chttp_t_187
# https://www.imdb.com/title/tt1392190/?ref_=chttp_t_188
# https://www.imdb.com/title/tt2267998/?ref_=chttp_t_189
# https://www.imdb.com/title/tt2119532/?ref_=chttp_t_190
# https://www.imdb.com/title/tt0015864/?ref_=chttp_t_191
# https://www.imdb.com/title/tt0097165/?ref_=chttp_t_192
# https://www.imdb.com/title/tt0353969/?ref_=chttp_t_193
# https://www.imdb.com/title/tt0107207/?ref_=chttp_t_194
# https://www.imdb.com/title/tt3011894/?ref_=chttp_t_195
# https://www.imdb.com/title/tt0077416/?ref_=chttp_t_196
# https://www.imdb.com/title/tt0198781/?ref_=chttp_t_197
# https://www.imdb.com/title/tt0017925/?ref_=chttp_t_198
# https://www.imdb.com/title/tt0047296/?ref_=chttp_t_199
# https://www.imdb.com/title/tt0015324/?ref_=chttp_t_200
# https://www.imdb.com/title/tt0892769/?ref_=chttp_t_201
# https://www.imdb.com/title/tt0073195/?ref_=chttp_t_202
# https://www.imdb.com/title/tt0041959/?ref_=chttp_t_203
# https://www.imdb.com/title/tt0046268/?ref_=chttp_t_204
# https://www.imdb.com/title/tt0978762/?ref_=chttp_t_205
# https://www.imdb.com/title/tt0050986/?ref_=chttp_t_206
# https://www.imdb.com/title/tt0382932/?ref_=chttp_t_207
# https://www.imdb.com/title/tt0031679/?ref_=chttp_t_208
# https://www.imdb.com/title/tt1950186/?ref_=chttp_t_209
# https://www.imdb.com/title/tt0046438/?ref_=chttp_t_210
# https://www.imdb.com/title/tt0118715/?ref_=chttp_t_211
# https://www.imdb.com/title/tt3170832/?ref_=chttp_t_212
# https://www.imdb.com/title/tt0075148/?ref_=chttp_t_213
# https://www.imdb.com/title/tt0050976/?ref_=chttp_t_214
# https://www.imdb.com/title/tt3315342/?ref_=chttp_t_215
# https://www.imdb.com/title/tt1895587/?ref_=chttp_t_216
# https://www.imdb.com/title/tt0395169/?ref_=chttp_t_217
# https://www.imdb.com/title/tt0088247/?ref_=chttp_t_218
# https://www.imdb.com/title/tt0091763/?ref_=chttp_t_219
# https://www.imdb.com/title/tt0113247/?ref_=chttp_t_220
# https://www.imdb.com/title/tt0019254/?ref_=chttp_t_221
# https://www.imdb.com/title/tt0381681/?ref_=chttp_t_222
# https://www.imdb.com/title/tt0036868/?ref_=chttp_t_223
# https://www.imdb.com/title/tt0325980/?ref_=chttp_t_224
# https://www.imdb.com/title/tt0070047/?ref_=chttp_t_225
# https://www.imdb.com/title/tt15097216/?ref_=chttp_t_226
# https://www.imdb.com/title/tt1979320/?ref_=chttp_t_227
# https://www.imdb.com/title/tt0074958/?ref_=chttp_t_228
# https://www.imdb.com/title/tt0032138/?ref_=chttp_t_229
# https://www.imdb.com/title/tt0092005/?ref_=chttp_t_230
# https://www.imdb.com/title/tt0317705/?ref_=chttp_t_231
# https://www.imdb.com/title/tt1028532/?ref_=chttp_t_232
# https://www.imdb.com/title/tt0476735/?ref_=chttp_t_233
# https://www.imdb.com/title/tt4016934/?ref_=chttp_t_234
# https://www.imdb.com/title/tt0059742/?ref_=chttp_t_235
# https://www.imdb.com/title/tt0758758/?ref_=chttp_t_236
# https://www.imdb.com/title/tt0035446/?ref_=chttp_t_237
# https://www.imdb.com/title/tt0058946/?ref_=chttp_t_238
# https://www.imdb.com/title/tt0032551/?ref_=chttp_t_239
# https://www.imdb.com/title/tt0107048/?ref_=chttp_t_240
# https://www.imdb.com/title/tt0245712/?ref_=chttp_t_241
# https://www.imdb.com/title/tt0129167/?ref_=chttp_t_242
# https://www.imdb.com/title/tt0032976/?ref_=chttp_t_243
# https://www.imdb.com/title/tt0061512/?ref_=chttp_t_244
# https://www.imdb.com/title/tt1454029/?ref_=chttp_t_245
# https://www.imdb.com/title/tt0025316/?ref_=chttp_t_246
# https://www.imdb.com/title/tt4430212/?ref_=chttp_t_247
# https://www.imdb.com/title/tt0099348/?ref_=chttp_t_248
# https://www.imdb.com/title/tt0103639/?ref_=chttp_t_249
# https://www.imdb.com/title/tt1954470/?ref_=chttp_t_250

# %%
budget_num = 0
gross_us_num = 0
open_week_rev_num = 0
open_week_date_std = "1900-01-01 00:00:00"
gross_world_num = 0
runtime = 0
color = "None"
aspect_ratio = "None"
sound_mix = "None"

# %%
url_test = 'https://www.imdb.com/title/tt0111161/?ref_=chttp_t_1'
browser2 = Chrome(options=chrome_options, service = service)
browser2.get(url_test)
content = browser2.page_source
soup = BeautifulSoup(content,'html.parser')

movie_title = soup.find("span",{"class":"hero__primary-text"}).text
print("Movie Title = " + movie_title)

box_office_elements = soup.find("div",{"data-testid":"title-boxoffice-section"})
if box_office_elements is not None:
    det_movie = box_office_elements.find_all("span",{"class":"ipc-metadata-list-item__list-content-item"})

    if len(det_movie) > 4:

        budget = det_movie[0].text
        gross_us = det_movie[1].text
        open_week_rev = det_movie[2].text
        open_week_date = det_movie[3].text            
        gross_world = det_movie[4].text

        print("budget = " + budget)
        print("gross_us = " + gross_us)
        print("opening_week_rev = " + open_week_rev)
        print("opening_week_date = " + open_week_date)
        print("gross_world = " + gross_world)
        print("=====================================")
        budget_num = int(re.sub("[A-Z£€₹$,()a-z]","",budget))
        gross_us_num = int(re.sub("[A-Z£€₹$,()a-z]","",gross_us))
        open_week_rev_num = int(re.sub("[A-Z£€₹$,()a-z]","",open_week_rev))
        open_week_date_std = datetime.strptime(open_week_date, "%b %d, %Y")
        gross_world_num = int(re.sub("[A-Z£€₹$,()a-z]","",gross_world))

        print("Data has been formatted to standard")
        print("-----------------------------------")
        print("budget =", budget_num)
        print("gross_us =" , gross_us_num)
        print("opening_week_rev =" , open_week_rev_num)
        print("opening_week_date =", open_week_date_std)
        print("gross_world =", gross_world_num)

technical_elements = soup.find("div",{"data-testid":"title-techspecs-section"})
if technical_elements is not None:
    det_detail = technical_elements.find_all("div",{"class":"ipc-metadata-list-item__content-container"})

    if len(det_detail) > 3:
        print("=====================================")
        print("Technical Specification")
        print("-----------------------------------")
        runtime = det_detail[0].text
        time = re.search(r'(\d+)\s*hours?\s*(\d+)\s*minutes?', runtime)
        hours = int(time.group(1)) if time.group(1) else 0
        minutes = int(time.group(2)) if time.group(2) else 0
        runtime = hours*60 + minutes
        color = det_detail[1].text
        sound = det_detail[2].text
        aspect_ratio = det_detail[3].text

        print("runtime =", runtime)
        print("color =", color)
        print("sound =", sound)
        print("aspect_ratio =", aspect_ratio)
# Out:
# Movie Title = The Shawshank Redemption
# budget = $25,000,000 (estimated)
# gross_us = $28,767,189
# opening_week_rev = $727,327
# opening_week_date = Sep 25, 1994
# gross_world = $29,322,669
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 25000000
# gross_us = 28767189
# opening_week_rev = 727327
# opening_week_date = 1994-09-25 00:00:00
# gross_world = 29322669

# %%
data = pd.read_csv('./data/imdb_primary_uas.csv', encoding='ISO-8859-1')
data.head()
# Out:
#                        Name  Year  Durasi(Menit)  Rating Rated
# 0  The Shawshank Redemption  1994          142.0     9.3    15
# 1             The Godfather  1972          175.0     9.3    15
# 2           The Dark Knight  2008          152.0     9.3   12A
# 3     The Godfather Part II  1974          202.0     9.3     X
# 4                 Angry Men  1957           96.0     9.3     U

# %% [markdown]
# #### buka file.txt sambil ambil datanya

# %%
browser2 = Chrome(options=chrome_options, service = service)
with open('./data/list_link.txt', 'r') as file:
    links = file.readlines()

with open('./data/imdb_secondary.csv', 'w') as f:
    headers = "Name,Budget,Gross_Us,Opening_Week,Open_Week_Date,Gross_World,Runtime,Color,Sound_Mix,Aspect_Ratio\n"
    f.write(headers)  
    for link in links:
        # Reset all the variables
        budget_num = 0
        gross_us_num = 0
        open_week_rev_num = 0
        open_week_date_std = "1900-01-01 00:00:00"
        gross_world_num = 0
        runtime = 0
        color = "None"
        aspect_ratio = "None"
        sound = "None"

        browser2.get(link)
        content = browser2.page_source
        soup = BeautifulSoup(content,'html.parser')
        movie_title = soup.find("span",{"class":"hero__primary-text"}).text
        print("Movie Title = " + movie_title)
        box_office_elements = soup.find("div",{"data-testid":"title-boxoffice-section"})
        if box_office_elements is not None:
            det_movie = box_office_elements.find_all("span",{"class":"ipc-metadata-list-item__list-content-item"})

            if len(det_movie) > 4:

                budget = det_movie[0].text
                gross_us = det_movie[1].text
                open_week_rev = det_movie[2].text
                open_week_date = det_movie[3].text            
                gross_world = det_movie[4].text

                print("budget = " + budget)
                print("gross_us = " + gross_us)
                print("opening_week_rev = " + open_week_rev)
                print("opening_week_date = " + open_week_date)
                print("gross_world = " + gross_world)
                print("=====================================")
                budget_num = int(re.sub("[A-Z£€₹¥₩$,()a-z]","",budget))
                gross_us_num = int(re.sub("[A-Z£€₹¥₩$,()a-z]","",gross_us))
                open_week_rev_num = int(re.sub("[A-Z£€₹¥₩$,()a-z]","",open_week_rev))
                open_week_date_std = datetime.strptime(open_week_date, "%b %d, %Y")
                gross_world_num = int(re.sub("[A-Z£€₹¥₩$,()a-z]","",gross_world))

                print("Data has been formatted to standard")
                print("-----------------------------------")
                print("budget =", budget_num)
                print("gross_us =" , gross_us_num)
                print("opening_week_rev =" , open_week_rev_num)
                print("opening_week_date =", open_week_date_std)
                print("gross_world =", gross_world_num)

        technical_elements = soup.find("div",{"data-testid":"title-techspecs-section"})
        if technical_elements is not None:
            det_detail = technical_elements.find_all("div",{"class":"ipc-metadata-list-item__content-container"})
        
            if len(det_detail) > 3:
                print("=====================================")
                print("Technical Specification")
                print("-----------------------------------")
                runtime = det_detail[0].text
                time = re.search(r'(\d+)\s*hours?\s*(\d+)\s*minutes?', runtime)
                if time is not None:
                    hours = int(time.group(1)) if time.group(1) else 0
                    minutes = int(time.group(2)) if time.group(2) else 0
                else:
                    hours = 0
                    minutes = 0
                runtime = hours*60 + minutes
                color = det_detail[1].text
                sound = det_detail[2].text
                aspect_ratio = det_detail[3].text

                print("runtime =", runtime)
                print("color =", color)
                print("sound =", sound)
                print("aspect_ratio =", aspect_ratio)
                print("=====================================")
        f.write(str(movie_title) + ',' + str(budget_num) + ',' + str(gross_us_num) + ',' + str(open_week_rev_num) + ',' + str(open_week_date_std) + ',' + str(gross_world_num) + ',' + str(runtime) + ',' + str(color) + ',' + str(sound) + ',' + str(aspect_ratio) + '\n')
# Out:
# Movie Title = The Shawshank Redemption
# budget = $25,000,000 (estimated)
# gross_us = $28,767,189
# opening_week_rev = $727,327
# opening_week_date = Sep 25, 1994
# gross_world = $29,322,669
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 25000000
# gross_us = 28767189
# opening_week_rev = 727327
# opening_week_date = 1994-09-25 00:00:00
# gross_world = 29322669
# Movie Title = The Godfather
# budget = $6,000,000 (estimated)
# gross_us = $136,381,073
# opening_week_rev = $302,393
# opening_week_date = Mar 19, 1972
# gross_world = $250,342,030
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 6000000
# gross_us = 136381073
# opening_week_rev = 302393
# opening_week_date = 1972-03-19 00:00:00
# gross_world = 250342030
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 175
# color = Color
# sound = Mono(RCA Sound Recording, original release)Dolby Digital
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = The Dark Knight
# budget = $185,000,000 (estimated)
# gross_us = $534,987,076
# opening_week_rev = $158,411,483
# opening_week_date = Jul 20, 2008
# gross_world = $1,008,497,140
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 185000000
# gross_us = 534987076
# opening_week_rev = 158411483
# opening_week_date = 2008-07-20 00:00:00
# gross_world = 1008497140
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 152
# color = Color
# sound = Dolby DigitalSDDSDTS
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = The Godfather Part II
# budget = $13,000,000 (estimated)
# gross_us = $47,834,595
# opening_week_rev = $171,417
# opening_week_date = Nov 10, 2019
# gross_world = $47,962,897
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 13000000
# gross_us = 47834595
# opening_week_rev = 171417
# opening_week_date = 2019-11-10 00:00:00
# gross_world = 47962897
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 202
# color = Color
# sound = Dolby Digital
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = 12 Angry Men
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 96
# color = Black and White
# sound = Mono
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = Schindler's List
# budget = $22,000,000 (estimated)
# gross_us = $96,898,818
# opening_week_rev = $656,636
# opening_week_date = Dec 19, 1993
# gross_world = $322,161,245
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 22000000
# gross_us = 96898818
# opening_week_rev = 656636
# opening_week_date = 1993-12-19 00:00:00
# gross_world = 322161245
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 195
# color = Black and WhiteColor
# sound = DTSDTS-Stereo
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = The Lord of the Rings: The Return of the King
# budget = $94,000,000 (estimated)
# gross_us = $379,427,292
# opening_week_rev = $72,629,713
# opening_week_date = Dec 21, 2003
# gross_world = $1,149,002,839
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 94000000
# gross_us = 379427292
# opening_week_rev = 72629713
# opening_week_date = 2003-12-21 00:00:00
# gross_world = 1149002839
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 201
# color = Color
# sound = DTS-ESDolby Digital EXSDDSDolby Atmos
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = Pulp Fiction
# budget = $8,000,000 (estimated)
# gross_us = $107,928,762
# opening_week_rev = $9,311,882
# opening_week_date = Oct 16, 1994
# gross_world = $213,928,762
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 8000000
# gross_us = 107928762
# opening_week_rev = 9311882
# opening_week_date = 1994-10-16 00:00:00
# gross_world = 213928762
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 154
# color = Color
# sound = Dolby DigitalDTS
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = The Lord of the Rings: The Fellowship of the Ring
# budget = $93,000,000 (estimated)
# gross_us = $318,572,165
# opening_week_rev = $47,211,490
# opening_week_date = Dec 23, 2001
# gross_world = $886,498,443
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 93000000
# gross_us = 318572165
# opening_week_rev = 47211490
# opening_week_date = 2001-12-23 00:00:00
# gross_world = 886498443
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 178
# color = Color
# sound = DTSSDDS
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = The Good, the Bad and the Ugly
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 148
# color = Color
# sound = Mono
# aspect_ratio = 2.35 : 1
# =====================================
# Movie Title = Forrest Gump
# budget = $55,000,000 (estimated)
# gross_us = $330,455,270
# opening_week_rev = $24,450,602
# opening_week_date = Jul 10, 1994
# gross_world = $678,226,465
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 55000000
# gross_us = 330455270
# opening_week_rev = 24450602
# opening_week_date = 1994-07-10 00:00:00
# gross_world = 678226465
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 142
# color = ColorBlack and White
# sound = Dolby SRSDDSDolby Atmos
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = The Lord of the Rings: The Two Towers
# budget = $94,000,000 (estimated)
# gross_us = $344,859,641
# opening_week_rev = $62,007,528
# opening_week_date = Dec 22, 2002
# gross_world = $950,852,619
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 94000000
# gross_us = 344859641
# opening_week_rev = 62007528
# opening_week_date = 2002-12-22 00:00:00
# gross_world = 950852619
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 179
# color = Color
# sound = DTS-ESDolby Digital EXSDDSDolby Atmos
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = Fight Club
# budget = $63,000,000 (estimated)
# gross_us = $37,030,102
# opening_week_rev = $11,035,485
# opening_week_date = Oct 17, 1999
# gross_world = $101,320,107
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 63000000
# gross_us = 37030102
# opening_week_rev = 11035485
# opening_week_date = 1999-10-17 00:00:00
# gross_world = 101320107
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 139
# color = Color
# sound = Dolby Digital
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = Inception
# budget = $160,000,000 (estimated)
# gross_us = $292,587,330
# opening_week_rev = $62,785,337
# opening_week_date = Jul 18, 2010
# gross_world = $839,030,630
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 160000000
# gross_us = 292587330
# opening_week_rev = 62785337
# opening_week_date = 2010-07-18 00:00:00
# gross_world = 839030630
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 148
# color = Color
# sound = Dolby DigitalDTSSDDS
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = Star Wars: Episode V - The Empire Strikes Back
# budget = $18,000,000 (estimated)
# gross_us = $292,753,960
# opening_week_rev = $4,910,483
# opening_week_date = May 25, 1980
# gross_world = $538,375,067
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 18000000
# gross_us = 292753960
# opening_week_rev = 4910483
# opening_week_date = 1980-05-25 00:00:00
# gross_world = 538375067
# Movie Title = The Matrix
# budget = $63,000,000 (estimated)
# gross_us = $172,076,928
# opening_week_rev = $27,788,331
# opening_week_date = Apr 4, 1999
# gross_world = $467,625,567
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 63000000
# gross_us = 172076928
# opening_week_rev = 27788331
# opening_week_date = 1999-04-04 00:00:00
# gross_world = 467625567
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 136
# color = Color
# sound = Dolby DigitalSDDSDolby Atmos
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = GoodFellas
# budget = $25,000,000 (estimated)
# gross_us = $46,909,721
# opening_week_rev = $6,368,901
# opening_week_date = Sep 23, 1990
# gross_world = $47,049,784
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 25000000
# gross_us = 46909721
# opening_week_rev = 6368901
# opening_week_date = 1990-09-23 00:00:00
# gross_world = 47049784
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 145
# color = Color
# sound = Dolby SR
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = One Flew Over the Cuckoo's Nest
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 133
# color = Color
# sound = Mono
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = Seven
# budget = $33,000,000 (estimated)
# gross_us = $100,125,643
# opening_week_rev = $13,949,807
# opening_week_date = Sep 24, 1995
# gross_world = $327,333,559
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 33000000
# gross_us = 100125643
# opening_week_rev = 13949807
# opening_week_date = 1995-09-24 00:00:00
# gross_world = 327333559
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 127
# color = Color
# sound = DTSDolby DigitalDTS 70 mm
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = Interstellar
# budget = $165,000,000 (estimated)
# gross_us = $188,020,017
# opening_week_rev = $47,510,360
# opening_week_date = Nov 9, 2014
# gross_world = $747,516,808
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 165000000
# gross_us = 188020017
# opening_week_rev = 47510360
# opening_week_date = 2014-11-09 00:00:00
# gross_world = 747516808
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 169
# color = Color
# sound = DatasatDolby DigitalIMAX 6-TrackDolby Surround 7.1
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = It's a Wonderful Life
# budget = $3,180,000 (estimated)
# gross_us = $1,483,643
# opening_week_rev = $44,000
# opening_week_date = Dec 20, 2020
# gross_world = $9,767,242
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 3180000
# gross_us = 1483643
# opening_week_rev = 44000
# opening_week_date = 2020-12-20 00:00:00
# gross_world = 9767242
# Movie Title = Seven Samurai
# budget = ¥125,000,000 (estimated)
# gross_us = $318,649
# opening_week_rev = $15,942
# opening_week_date = Jul 28, 2002
# gross_world = $346,258
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 125000000
# gross_us = 318649
# opening_week_rev = 15942
# opening_week_date = 2002-07-28 00:00:00
# gross_world = 346258
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 207
# color = Black and White
# sound = Mono
# aspect_ratio = 1.37 : 1
# =====================================
# Movie Title = The Silence of the Lambs
# budget = $19,000,000 (estimated)
# gross_us = $130,742,922
# opening_week_rev = $13,766,814
# opening_week_date = Feb 18, 1991
# gross_world = $272,742,922
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 19000000
# gross_us = 130742922
# opening_week_rev = 13766814
# opening_week_date = 1991-02-18 00:00:00
# gross_world = 272742922
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 118
# color = Color
# sound = Dolby SRDolby Stereo
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = Saving Private Ryan
# budget = $70,000,000 (estimated)
# gross_us = $217,049,603
# opening_week_rev = $30,576,104
# opening_week_date = Jul 26, 1998
# gross_world = $482,351,251
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 70000000
# gross_us = 217049603
# opening_week_rev = 30576104
# opening_week_date = 1998-07-26 00:00:00
# gross_world = 482351251
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 169
# color = Color
# sound = DTSDolby DigitalSDDSDolby AtmosDolby Digital EXDolby Stereo
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = City of God
# budget = R$3,300,000 (estimated)
# gross_us = $7,564,459
# opening_week_rev = $88,292
# opening_week_date = Jan 19, 2003
# gross_world = $30,680,793
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 3300000
# gross_us = 7564459
# opening_week_rev = 88292
# opening_week_date = 2003-01-19 00:00:00
# gross_world = 30680793
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 130
# color = Color
# sound = Dolby DigitalSDDS
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = Life Is Beautiful
# budget = $20,000,000 (estimated)
# gross_us = $57,563,264
# opening_week_rev = $118,920
# opening_week_date = Oct 25, 1998
# gross_world = $230,099,013
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 20000000
# gross_us = 57563264
# opening_week_rev = 118920
# opening_week_date = 1998-10-25 00:00:00
# gross_world = 230099013
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 116
# color = Color
# sound = Dolby Digital
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = The Green Mile
# budget = $60,000,000 (estimated)
# gross_us = $136,801,374
# opening_week_rev = $18,017,152
# opening_week_date = Dec 12, 1999
# gross_world = $286,801,374
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 60000000
# gross_us = 136801374
# opening_week_rev = 18017152
# opening_week_date = 1999-12-12 00:00:00
# gross_world = 286801374
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 189
# color = Color
# sound = DTSDolby DigitalSDDS
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = Terminator 2: Judgment Day
# budget = $102,000,000 (estimated)
# gross_us = $205,881,154
# opening_week_rev = $31,765,506
# opening_week_date = Jul 7, 1991
# gross_world = $520,881,154
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 102000000
# gross_us = 205881154
# opening_week_rev = 31765506
# opening_week_date = 1991-07-07 00:00:00
# gross_world = 520881154
# Movie Title = Star Wars: Episode IV - A New Hope
# budget = $11,000,000 (estimated)
# gross_us = $460,998,507
# opening_week_rev = $1,554,475
# opening_week_date = May 30, 1977
# gross_world = $775,398,507
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 11000000
# gross_us = 460998507
# opening_week_rev = 1554475
# opening_week_date = 1977-05-30 00:00:00
# gross_world = 775398507
# Movie Title = Dune: Part Two
# budget = $190,000,000 (estimated)
# gross_us = $282,144,358
# opening_week_rev = $82,505,391
# opening_week_date = Mar 3, 2024
# gross_world = $711,844,358
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 190000000
# gross_us = 282144358
# opening_week_rev = 82505391
# opening_week_date = 2024-03-03 00:00:00
# gross_world = 711844358
# Movie Title = Back to the Future
# budget = $19,000,000 (estimated)
# gross_us = $214,077,472
# opening_week_rev = $11,152,500
# opening_week_date = Jul 7, 1985
# gross_world = $384,577,472
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 19000000
# gross_us = 214077472
# opening_week_rev = 11152500
# opening_week_date = 1985-07-07 00:00:00
# gross_world = 384577472
# Movie Title = Spirited Away
# budget = $19,000,000 (estimated)
# gross_us = $15,205,725
# opening_week_rev = $449,839
# opening_week_date = Sep 22, 2002
# gross_world = $357,561,772
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 19000000
# gross_us = 15205725
# opening_week_rev = 449839
# opening_week_date = 2002-09-22 00:00:00
# gross_world = 357561772
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 125
# color = Color
# sound = DTS-ESDolby Digital EX
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = The Pianist
# budget = $35,000,000 (estimated)
# gross_us = $32,590,750
# opening_week_rev = $111,261
# opening_week_date = Dec 29, 2002
# gross_world = $120,098,945
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 35000000
# gross_us = 32590750
# opening_week_rev = 111261
# opening_week_date = 2002-12-29 00:00:00
# gross_world = 120098945
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 150
# color = Color
# sound = DTSDolby Digital
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = Parasite
# budget = $11,400,000 (estimated)
# gross_us = $53,369,749
# opening_week_rev = $393,216
# opening_week_date = Oct 13, 2019
# gross_world = $262,099,264
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 11400000
# gross_us = 53369749
# opening_week_rev = 393216
# opening_week_date = 2019-10-13 00:00:00
# gross_world = 262099264
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 132
# color = Color
# sound = Dolby Atmos
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = Psycho
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 109
# color = Black and White
# sound = Dolby Digital
# aspect_ratio = 1.37 : 1(original & negative ratio, open matte)
# =====================================
# Movie Title = Gladiator
# budget = $103,000,000 (estimated)
# gross_us = $187,705,427
# opening_week_rev = $34,819,017
# opening_week_date = May 7, 2000
# gross_world = $465,387,186
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 103000000
# gross_us = 187705427
# opening_week_rev = 34819017
# opening_week_date = 2000-05-07 00:00:00
# gross_world = 465387186
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 155
# color = Color
# sound = SDDSDolby DigitalDolby Atmos
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = Spider-Man: Across the Spider-Verse
# budget = $150,000,000 (estimated)
# gross_us = $381,593,754
# opening_week_rev = $120,663,589
# opening_week_date = Jun 4, 2023
# gross_world = $690,897,910
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 150000000
# gross_us = 381593754
# opening_week_rev = 120663589
# opening_week_date = 2023-06-04 00:00:00
# gross_world = 690897910
# Movie Title = The Lion King
# budget = $45,000,000 (estimated)
# gross_us = $422,783,777
# opening_week_rev = $1,586,753
# opening_week_date = Jun 19, 1994
# gross_world = $968,750,709
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 45000000
# gross_us = 422783777
# opening_week_rev = 1586753
# opening_week_date = 1994-06-19 00:00:00
# gross_world = 968750709
# Movie Title = The Departed
# budget = $90,000,000 (estimated)
# gross_us = $132,399,394
# opening_week_rev = $26,887,467
# opening_week_date = Oct 8, 2006
# gross_world = $291,481,358
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 90000000
# gross_us = 132399394
# opening_week_rev = 26887467
# opening_week_date = 2006-10-08 00:00:00
# gross_world = 291481358
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 151
# color = Color
# sound = Dolby DigitalSDDSDTS
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = Leon
# budget = FRF 115,000,000 (estimated)
# gross_us = $19,501,238
# opening_week_rev = $5,306,558
# opening_week_date = Nov 20, 1994
# gross_world = $20,275,438
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 115000000
# gross_us = 19501238
# opening_week_rev = 5306558
# opening_week_date = 1994-11-20 00:00:00
# gross_world = 20275438
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 110
# color = Color
# sound = Dolby DigitalDolby Atmos
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = American History X
# budget = $20,000,000 (estimated)
# gross_us = $6,719,864
# opening_week_rev = $156,076
# opening_week_date = Nov 1, 1998
# gross_world = $23,875,714
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 20000000
# gross_us = 6719864
# opening_week_rev = 156076
# opening_week_date = 1998-11-01 00:00:00
# gross_world = 23875714
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 119
# color = Color
# sound = Dolby Digital
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = Whiplash
# budget = $3,300,000 (estimated)
# gross_us = $13,092,000
# opening_week_rev = $135,388
# opening_week_date = Oct 12, 2014
# gross_world = $49,449,489
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 3300000
# gross_us = 13092000
# opening_week_rev = 135388
# opening_week_date = 2014-10-12 00:00:00
# gross_world = 49449489
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 106
# color = Color
# sound = Dolby DigitalSDDSDatasatDolby Atmos
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = The Prestige
# budget = $40,000,000 (estimated)
# gross_us = $53,089,891
# opening_week_rev = $14,801,808
# opening_week_date = Oct 22, 2006
# gross_world = $109,676,311
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 40000000
# gross_us = 53089891
# opening_week_rev = 14801808
# opening_week_date = 2006-10-22 00:00:00
# gross_world = 109676311
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 130
# color = Color
# sound = SDDSDolby DigitalDTS
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = Grave of the Fireflies
# budget = $3,700,000 (estimated)
# gross_us = $516,962
# opening_week_rev = $158,101
# opening_week_date = Aug 12, 2018
# gross_world = $519,421
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 3700000
# gross_us = 516962
# opening_week_rev = 158101
# opening_week_date = 2018-08-12 00:00:00
# gross_world = 519421
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 89
# color = Color
# sound = Dolby StereoStereo
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = Harakiri
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 133
# color = Black and White
# sound = Mono
# aspect_ratio = 2.35 : 1
# =====================================
# Movie Title = The Usual Suspects
# budget = $6,000,000 (estimated)
# gross_us = $23,341,568
# opening_week_rev = $645,363
# opening_week_date = Aug 20, 1995
# gross_world = $23,341,568
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 6000000
# gross_us = 23341568
# opening_week_rev = 645363
# opening_week_date = 1995-08-20 00:00:00
# gross_world = 23341568
# Movie Title = Casablanca
# budget = $950,000 (estimated)
# gross_us = $4,219,709
# opening_week_rev = $181,494
# opening_week_date = Apr 12, 1992
# gross_world = $4,661,588
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 950000
# gross_us = 4219709
# opening_week_rev = 181494
# opening_week_date = 1992-04-12 00:00:00
# gross_world = 4661588
# Movie Title = Untouchable
# budget = €9,500,000 (estimated)
# gross_us = $10,198,820
# opening_week_rev = $103,507
# opening_week_date = May 27, 2012
# gross_world = $426,590,315
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 9500000
# gross_us = 10198820
# opening_week_rev = 103507
# opening_week_date = 2012-05-27 00:00:00
# gross_world = 426590315
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 112
# color = Color
# sound = Dolby Digital
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = Cinema Paradiso
# budget = $5,000,000 (estimated)
# gross_us = $12,397,210
# opening_week_rev = $16,552
# opening_week_date = Feb 4, 1990
# gross_world = $13,020,497
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 5000000
# gross_us = 12397210
# opening_week_rev = 16552
# opening_week_date = 1990-02-04 00:00:00
# gross_world = 13020497
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 174
# color = Color
# sound = Mono
# aspect_ratio = 1.66 : 1
# =====================================
# Movie Title = Modern Times
# budget = $1,500,000 (estimated)
# gross_us = $163,577
# opening_week_rev = $35,809
# opening_week_date = Dec 28, 2003
# gross_world = $463,618
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 1500000
# gross_us = 163577
# opening_week_rev = 35809
# opening_week_date = 2003-12-28 00:00:00
# gross_world = 463618
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 87
# color = Black and White
# sound = Silent
# aspect_ratio = 1.37 : 1
# =====================================
# Movie Title = Rear Window
# Movie Title = Once Upon a Time in the West
# Movie Title = Alien
# budget = $11,000,000 (estimated)
# gross_us = $84,206,106
# opening_week_rev = $3,527,881
# opening_week_date = May 28, 1979
# gross_world = $108,591,169
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 11000000
# gross_us = 84206106
# opening_week_rev = 3527881
# opening_week_date = 1979-05-28 00:00:00
# gross_world = 108591169
# Movie Title = City Lights
# budget = $1,500,000 (estimated)
# gross_us = $19,181
# opening_week_rev = $9,102
# opening_week_date = Jul 8, 2007
# gross_world = $50,419
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 1500000
# gross_us = 19181
# opening_week_rev = 9102
# opening_week_date = 2007-07-08 00:00:00
# gross_world = 50419
# Movie Title = Django Unchained
# budget = $100,000,000 (estimated)
# gross_us = $162,805,434
# opening_week_rev = $30,122,888
# opening_week_date = Dec 30, 2012
# gross_world = $426,076,293
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 100000000
# gross_us = 162805434
# opening_week_rev = 30122888
# opening_week_date = 2012-12-30 00:00:00
# gross_world = 426076293
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 165
# color = Color
# sound = SDDSDatasatDolby Digital
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = Apocalypse Now
# budget = $31,500,000 (estimated)
# gross_us = $96,042,913
# opening_week_rev = $118,558
# opening_week_date = Aug 19, 1979
# gross_world = $104,920,499
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 31500000
# gross_us = 96042913
# opening_week_rev = 118558
# opening_week_date = 1979-08-19 00:00:00
# gross_world = 104920499
# Movie Title = Memento
# budget = $9,000,000 (estimated)
# gross_us = $25,544,867
# opening_week_rev = $235,488
# opening_week_date = Mar 18, 2001
# gross_world = $40,047,236
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 9000000
# gross_us = 25544867
# opening_week_rev = 235488
# opening_week_date = 2001-03-18 00:00:00
# gross_world = 40047236
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 113
# color = ColorBlack and White
# sound = Dolby Digital
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = WALL·E
# budget = $180,000,000 (estimated)
# gross_us = $223,808,164
# opening_week_rev = $63,087,526
# opening_week_date = Jun 29, 2008
# gross_world = $521,320,168
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 180000000
# gross_us = 223808164
# opening_week_rev = 63087526
# opening_week_date = 2008-06-29 00:00:00
# gross_world = 521320168
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 98
# color = Color
# sound = DTSSDDSDolby DigitalDolby Atmos
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = 12th Fail
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 147
# color = Color
# sound = Dolby AtmosDolby Digital
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = Raiders of the Lost Ark
# budget = $18,000,000 (estimated)
# gross_us = $248,159,971
# opening_week_rev = $8,305,823
# opening_week_date = Jun 14, 1981
# gross_world = $389,925,971
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 18000000
# gross_us = 248159971
# opening_week_rev = 8305823
# opening_week_date = 1981-06-14 00:00:00
# gross_world = 389925971
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 115
# color = Color
# sound = Dolby Atmos
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = The Lives of Others
# budget = $2,000,000 (estimated)
# gross_us = $11,286,112
# opening_week_rev = $223,000
# opening_week_date = Feb 11, 2007
# gross_world = $77,357,476
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 2000000
# gross_us = 11286112
# opening_week_rev = 223000
# opening_week_date = 2007-02-11 00:00:00
# gross_world = 77357476
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 137
# color = Color
# sound = Dolby Digital
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = Sunset Blvd.
# budget = $1,752,000 (estimated)
# gross_us = $299,645
# opening_week_rev = $169,067
# opening_week_date = May 13, 2018
# gross_world = $304,474
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 1752000
# gross_us = 299645
# opening_week_rev = 169067
# opening_week_date = 2018-05-13 00:00:00
# gross_world = 304474
# Movie Title = Avengers: Infinity War
# budget = $321,000,000 (estimated)
# gross_us = $678,815,482
# opening_week_rev = $257,698,183
# opening_week_date = Apr 29, 2018
# gross_world = $2,052,415,039
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 321000000
# gross_us = 678815482
# opening_week_rev = 257698183
# opening_week_date = 2018-04-29 00:00:00
# gross_world = 2052415039
# Movie Title = Paths of Glory
# Movie Title = Spider-Man: Into the Spider-Verse
# budget = $90,000,000 (estimated)
# gross_us = $190,241,310
# opening_week_rev = $35,363,376
# opening_week_date = Dec 16, 2018
# gross_world = $384,298,736
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 90000000
# gross_us = 190241310
# opening_week_rev = 35363376
# opening_week_date = 2018-12-16 00:00:00
# gross_world = 384298736
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 117
# color = Color
# sound = Dolby AtmosDolby Surround 7.112-Track Digital SoundDolby DigitalSDDS
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = Witness for the Prosecution
# Movie Title = The Shining
# budget = $19,000,000 (estimated)
# gross_us = $45,634,352
# opening_week_rev = $622,337
# opening_week_date = May 26, 1980
# gross_world = $47,516,353
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 19000000
# gross_us = 45634352
# opening_week_rev = 622337
# opening_week_date = 1980-05-26 00:00:00
# gross_world = 47516353
# Movie Title = The Great Dictator
# Movie Title = Aliens
# budget = $18,500,000 (estimated)
# gross_us = $85,160,248
# opening_week_rev = $10,052,042
# opening_week_date = Jul 20, 1986
# gross_world = $131,060,248
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 18500000
# gross_us = 85160248
# opening_week_rev = 10052042
# opening_week_date = 1986-07-20 00:00:00
# gross_world = 131060248
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 137
# color = Color
# sound = Dolby StereoMono
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = Inglourious Basterds
# budget = $70,000,000 (estimated)
# gross_us = $120,540,719
# opening_week_rev = $38,054,676
# opening_week_date = Aug 23, 2009
# gross_world = $321,458,605
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 70000000
# gross_us = 120540719
# opening_week_rev = 38054676
# opening_week_date = 2009-08-23 00:00:00
# gross_world = 321458605
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 153
# color = Color
# sound = SDDSDolby DigitalDTS
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = The Dark Knight Rises
# budget = $250,000,000 (estimated)
# gross_us = $448,149,584
# opening_week_rev = $160,887,295
# opening_week_date = Jul 22, 2012
# gross_world = $1,085,289,416
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 250000000
# gross_us = 448149584
# opening_week_rev = 160887295
# opening_week_date = 2012-07-22 00:00:00
# gross_world = 1085289416
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 164
# color = Color
# sound = SDDSDatasatDolby DigitalIMAX 6-Track
# aspect_ratio = 1.78 : 1(IMAX version, original ratio)2.39 : 12.39 : 1(IMAX version, original ratio)
# =====================================
# Movie Title = Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# budget = $1,800,000 (estimated)
# gross_us = $9,440,272
# opening_week_rev = $11,751
# opening_week_date = Jul 17, 1994
# gross_world = $9,631,984
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 1800000
# gross_us = 9440272
# opening_week_rev = 11751
# opening_week_date = 1994-07-17 00:00:00
# gross_world = 9631984
# Movie Title = Coco
# budget = $175,000,000 (estimated)
# gross_us = $210,460,015
# opening_week_rev = $50,802,605
# opening_week_date = Nov 26, 2017
# gross_world = $814,337,054
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 175000000
# gross_us = 210460015
# opening_week_rev = 50802605
# opening_week_date = 2017-11-26 00:00:00
# gross_world = 814337054
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 105
# color = Color
# sound = Dolby AtmosAuro 11.1Dolby Surround 7.112-Track Digital SoundDolby DigitalSDDS
# aspect_ratio = 2.35 : 1
# =====================================
# Movie Title = Oldboy
# budget = $3,000,000 (estimated)
# gross_us = $2,458,200
# opening_week_rev = $68,957
# opening_week_date = Mar 27, 2005
# gross_world = $17,542,965
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 3000000
# gross_us = 2458200
# opening_week_rev = 68957
# opening_week_date = 2005-03-27 00:00:00
# gross_world = 17542965
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 0
# color = Color
# sound = Dolby DigitalDolby Surround 7.1
# aspect_ratio = 2.35 : 1
# =====================================
# Movie Title = American Beauty
# budget = $15,000,000 (estimated)
# gross_us = $130,096,601
# opening_week_rev = $861,531
# opening_week_date = Sep 19, 1999
# gross_world = $356,296,601
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 15000000
# gross_us = 130096601
# opening_week_rev = 861531
# opening_week_date = 1999-09-19 00:00:00
# gross_world = 356296601
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 122
# color = ColorBlack and White
# sound = DTSDolby DigitalSDDSDolby
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = Amadeus
# budget = $18,000,000 (estimated)
# gross_us = $51,973,029
# opening_week_rev = $505,276
# opening_week_date = Sep 23, 1984
# gross_world = $52,071,304
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 18000000
# gross_us = 51973029
# opening_week_rev = 505276
# opening_week_date = 1984-09-23 00:00:00
# gross_world = 52071304
# Movie Title = Toy Story
# budget = $30,000,000 (estimated)
# gross_us = $223,225,679
# opening_week_rev = $29,140,617
# opening_week_date = Nov 26, 1995
# gross_world = $394,436,586
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 30000000
# gross_us = 223225679
# opening_week_rev = 29140617
# opening_week_date = 1995-11-26 00:00:00
# gross_world = 394436586
# Movie Title = Avengers: Endgame
# budget = $356,000,000 (estimated)
# gross_us = $858,373,000
# opening_week_rev = $357,115,007
# opening_week_date = Apr 28, 2019
# gross_world = $2,799,439,100
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 356000000
# gross_us = 858373000
# opening_week_rev = 357115007
# opening_week_date = 2019-04-28 00:00:00
# gross_world = 2799439100
# Movie Title = Das Boot
# budget = DEM 32,000,000 (estimated)
# gross_us = $11,487,676
# opening_week_rev = $26,994
# opening_week_date = Feb 14, 1982
# gross_world = $11,488,778
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 32000000
# gross_us = 11487676
# opening_week_rev = 26994
# opening_week_date = 1982-02-14 00:00:00
# gross_world = 11488778
# Movie Title = Braveheart
# budget = $72,000,000 (estimated)
# gross_us = $75,609,945
# opening_week_rev = $9,938,276
# opening_week_date = May 28, 1995
# gross_world = $213,216,216
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 72000000
# gross_us = 75609945
# opening_week_rev = 9938276
# opening_week_date = 1995-05-28 00:00:00
# gross_world = 213216216
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 178
# color = Color
# sound = DTSDolby DigitalDolby Atmos
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = Good Will Hunting
# budget = $10,000,000 (estimated)
# gross_us = $138,433,435
# opening_week_rev = $272,912
# opening_week_date = Dec 7, 1997
# gross_world = $225,933,435
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 10000000
# gross_us = 138433435
# opening_week_rev = 272912
# opening_week_date = 1997-12-07 00:00:00
# gross_world = 225933435
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 126
# color = Color
# sound = Dolby Digital
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = Princess Mononoke
# budget = ¥2,400,000,000 (estimated)
# gross_us = $4,845,631
# opening_week_rev = $144,446
# opening_week_date = Oct 31, 1999
# gross_world = $170,212,483
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 2400000000
# gross_us = 4845631
# opening_week_rev = 144446
# opening_week_date = 1999-10-31 00:00:00
# gross_world = 170212483
# Movie Title = Joker
# budget = $55,000,000 (estimated)
# gross_us = $335,477,657
# opening_week_rev = $96,202,337
# opening_week_date = Oct 6, 2019
# gross_world = $1,078,958,629
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 55000000
# gross_us = 335477657
# opening_week_rev = 96202337
# opening_week_date = 2019-10-06 00:00:00
# gross_world = 1078958629
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 122
# color = Color
# sound = SDDSDolby AtmosDatasatDolby Digital
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = Your Name.
# budget = ¥370,000,000 (estimated)
# gross_us = $5,017,246
# opening_week_rev = $1,813,781
# opening_week_date = Apr 9, 2017
# gross_world = $382,238,191
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 370000000
# gross_us = 5017246
# opening_week_rev = 1813781
# opening_week_date = 2017-04-09 00:00:00
# gross_world = 382238191
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 106
# color = Color
# sound = Dolby Digital
# aspect_ratio = 1.78 : 1(original ratio)
# =====================================
# Movie Title = High and Low
# Movie Title = Once Upon a Time in America
# budget = $30,000,000 (estimated)
# gross_us = $5,321,508
# opening_week_rev = $2,412,014
# opening_week_date = Jun 3, 1984
# gross_world = $5,475,086
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 30000000
# gross_us = 5321508
# opening_week_rev = 2412014
# opening_week_date = 1984-06-03 00:00:00
# gross_world = 5475086
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 229
# color = Color
# sound = MonoDolby Digital
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = 3 Idiots
# budget = ₹550,000,000 (estimated)
# gross_us = $6,532,874
# opening_week_rev = $1,645,502
# opening_week_date = Dec 27, 2009
# gross_world = $60,262,836
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 550000000
# gross_us = 6532874
# opening_week_rev = 1645502
# opening_week_date = 2009-12-27 00:00:00
# gross_world = 60262836
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 170
# color = Color
# sound = Dolby DigitalDTS
# aspect_ratio = 2.35 : 1
# =====================================
# Movie Title = Singin' in the Rain
# budget = $2,540,800 (estimated)
# gross_us = $1,884,537
# opening_week_rev = $13,643
# opening_week_date = Nov 10, 2002
# gross_world = $2,010,042
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 2540800
# gross_us = 1884537
# opening_week_rev = 13643
# opening_week_date = 2002-11-10 00:00:00
# gross_world = 2010042
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 103
# color = ColorBlack and White
# sound = Dolby Digital
# aspect_ratio = 1.37 : 1
# =====================================
# Movie Title = Capernaum
# budget = $4,000,000 (estimated)
# gross_us = $1,661,096
# opening_week_rev = $24,988
# opening_week_date = Dec 16, 2018
# gross_world = $64,417,003
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 4000000
# gross_us = 1661096
# opening_week_rev = 24988
# opening_week_date = 2018-12-16 00:00:00
# gross_world = 64417003
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 126
# color = Color
# sound = Dolby Digital
# aspect_ratio = 2.35 : 1
# =====================================
# Movie Title = Come and See
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 142
# color = Color
# sound = Mono
# aspect_ratio = 1.37 : 1
# =====================================
# Movie Title = Requiem for a Dream
# budget = $4,500,000 (estimated)
# gross_us = $3,635,482
# opening_week_rev = $64,770
# opening_week_date = Oct 8, 2000
# gross_world = $7,390,108
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 4500000
# gross_us = 3635482
# opening_week_rev = 64770
# opening_week_date = 2000-10-08 00:00:00
# gross_world = 7390108
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 102
# color = Color
# sound = Dolby Surround 7.1Dolby DigitalDolby Atmos
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = Toy Story 3
# budget = $200,000,000 (estimated)
# gross_us = $415,004,880
# opening_week_rev = $110,307,189
# opening_week_date = Jun 20, 2010
# gross_world = $1,067,316,101
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 200000000
# gross_us = 415004880
# opening_week_rev = 110307189
# opening_week_date = 2010-06-20 00:00:00
# gross_world = 1067316101
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 103
# color = Color
# sound = SDDSDolby DigitalDolby Surround 7.1Dolby Atmos
# aspect_ratio = 1.78 : 1(original & intended ratio, Blu-ray)
# =====================================
# Movie Title = Star Wars: Episode VI - Return of the Jedi
# budget = $32,500,000 (estimated)
# gross_us = $316,566,101
# opening_week_rev = $23,019,618
# opening_week_date = May 29, 1983
# gross_world = $475,106,177
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 32500000
# gross_us = 316566101
# opening_week_rev = 23019618
# opening_week_date = 1983-05-29 00:00:00
# gross_world = 475106177
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 131
# color = Color
# sound = Dolby Stereo
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = Eternal Sunshine of the Spotless Mind
# ...
# budget = 15000000
# gross_us = 19301403
# opening_week_rev = 5533844
# opening_week_date = 1998-03-08 00:00:00
# gross_world = 48066229
# Movie Title = Room
# budget = $13,000,000 (estimated)
# gross_us = $14,677,654
# opening_week_rev = $118,298
# opening_week_date = Oct 18, 2015
# gross_world = $35,402,766
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 13000000
# gross_us = 14677654
# opening_week_rev = 118298
# opening_week_date = 2015-10-18 00:00:00
# gross_world = 35402766
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 118
# color = Color
# sound = Dolby DigitalDatasatDolby Atmos
# aspect_ratio = 2.35 : 12.39 : 1
# =====================================
# Movie Title = Rocky
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 0
# color = Color
# sound = MonoDolby Digital
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = The Seventh Seal
# Movie Title = Logan
# budget = $97,000,000 (estimated)
# gross_us = $226,277,068
# opening_week_rev = $88,411,916
# opening_week_date = Mar 5, 2017
# gross_world = $619,180,476
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 97000000
# gross_us = 226277068
# opening_week_rev = 88411916
# opening_week_date = 2017-03-05 00:00:00
# gross_world = 619180476
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 137
# color = Color
# sound = Dolby AtmosDolby DigitalDolby Surround 7.1SDDS
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = Spotlight
# budget = $20,000,000 (estimated)
# gross_us = $45,055,776
# opening_week_rev = $295,009
# opening_week_date = Nov 8, 2015
# gross_world = $98,690,254
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 20000000
# gross_us = 45055776
# opening_week_rev = 295009
# opening_week_date = 2015-11-08 00:00:00
# gross_world = 98690254
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 129
# color = Color
# sound = Dolby Digital
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = Hotel Rwanda
# budget = $17,500,000 (estimated)
# gross_us = $23,530,892
# opening_week_rev = $100,091
# opening_week_date = Dec 26, 2004
# gross_world = $33,882,243
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 17500000
# gross_us = 23530892
# opening_week_rev = 100091
# opening_week_date = 2004-12-26 00:00:00
# gross_world = 33882243
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 121
# color = Color
# sound = DTSDolby Digital
# aspect_ratio = 2.35 : 1
# =====================================
# Movie Title = The Terminator
# budget = $6,400,000 (estimated)
# gross_us = $38,371,200
# opening_week_rev = $4,020,663
# opening_week_date = Oct 28, 1984
# gross_world = $78,371,200
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 6400000
# gross_us = 38371200
# opening_week_rev = 4020663
# opening_week_date = 1984-10-28 00:00:00
# gross_world = 78371200
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 107
# color = Color
# sound = Mono(original release)
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = Platoon
# budget = $6,000,000 (estimated)
# gross_us = $138,530,565
# opening_week_rev = $241,080
# opening_week_date = Dec 21, 1986
# gross_world = $138,545,632
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 6000000
# gross_us = 138530565
# opening_week_rev = 241080
# opening_week_date = 1986-12-21 00:00:00
# gross_world = 138545632
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 0
# color = Color
# sound = Dolby StereoDolby Digital
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = La haine
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 98
# color = Black and White
# sound = Dolby Digital
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = The Passion of Joan of Arc
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 110
# color = Black and White
# sound = Silent
# aspect_ratio = 1.33 : 1
# =====================================
# Movie Title = Before Sunset
# budget = $2,700,000 (estimated)
# gross_us = $5,820,649
# opening_week_rev = $219,425
# opening_week_date = Jul 4, 2004
# gross_world = $15,855,022
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 2700000
# gross_us = 5820649
# opening_week_rev = 219425
# opening_week_date = 2004-07-04 00:00:00
# gross_world = 15855022
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 80
# color = Color
# sound = DTSDolby DigitalSDDS
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = The Best Years of Our Lives
# Movie Title = Pirates of the Caribbean: The Curse of the Black Pearl
# budget = $140,000,000 (estimated)
# gross_us = $305,413,918
# opening_week_rev = $46,630,690
# opening_week_date = Jul 13, 2003
# gross_world = $654,264,546
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 140000000
# gross_us = 305413918
# opening_week_rev = 46630690
# opening_week_date = 2003-07-13 00:00:00
# gross_world = 654264546
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 143
# color = Color
# sound = Dolby Digital EXSDDSDTS
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = The Exorcist
# budget = $11,000,000 (estimated)
# gross_us = $233,005,644
# opening_week_rev = $8,175,666
# opening_week_date = Sep 24, 2000
# gross_world = $441,306,145
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 11000000
# gross_us = 233005644
# opening_week_rev = 8175666
# opening_week_date = 2000-09-24 00:00:00
# gross_world = 441306145
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 122
# color = Color
# sound = Mono(original release)
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = Jai Bhim
# Movie Title = Rush
# budget = $38,000,000 (estimated)
# gross_us = $26,947,624
# opening_week_rev = $187,289
# opening_week_date = Sep 22, 2013
# gross_world = $96,992,516
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 38000000
# gross_us = 26947624
# opening_week_rev = 187289
# opening_week_date = 2013-09-22 00:00:00
# gross_world = 96992516
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 123
# color = Color
# sound = Dolby DigitalDatasatSDDS
# aspect_ratio = 2.35 : 1
# =====================================
# Movie Title = Network
# Movie Title = The Wizard of Oz
# budget = $2,777,000 (estimated)
# gross_us = $24,668,669
# opening_week_rev = $5,354,311
# opening_week_date = Nov 8, 1998
# gross_world = $25,637,669
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 2777000
# gross_us = 24668669
# opening_week_rev = 5354311
# opening_week_date = 1998-11-08 00:00:00
# gross_world = 25637669
# Movie Title = Stand by Me
# budget = $8,000,000 (estimated)
# gross_us = $52,287,414
# opening_week_rev = $242,795
# opening_week_date = Aug 10, 1986
# gross_world = $52,290,509
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 8000000
# gross_us = 52287414
# opening_week_rev = 242795
# opening_week_date = 1986-08-10 00:00:00
# gross_world = 52290509
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 89
# color = Color
# sound = Dolby AtmosDolby DigitalMono
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = The Incredibles
# budget = $92,000,000 (estimated)
# gross_us = $261,441,092
# opening_week_rev = $70,467,623
# opening_week_date = Nov 7, 2004
# gross_world = $631,688,498
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 92000000
# gross_us = 261441092
# opening_week_rev = 70467623
# opening_week_date = 2004-11-07 00:00:00
# gross_world = 631688498
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 115
# color = Black and WhiteColor
# sound = Dolby Digital EX
# aspect_ratio = 2.39 : 12.35 : 1
# =====================================
# Movie Title = Hachi: A Dog's Tale
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 93
# color = Color
# sound = DTSDolby DigitalSDDS
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = My Father and My Son
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 112
# color = Color
# sound = Dolby Digital
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = The Handmaiden
# budget = ₩10,000,000,000 (estimated)
# gross_us = $2,006,788
# opening_week_rev = $92,129
# opening_week_date = Oct 23, 2016
# gross_world = $37,863,670
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 10000000000
# gross_us = 2006788
# opening_week_rev = 92129
# opening_week_date = 2016-10-23 00:00:00
# gross_world = 37863670
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 145
# color = Color
# sound = Dolby DigitalDolby AtmosDolby Surround 7.1
# aspect_ratio = 2.35 : 1
# =====================================
# Movie Title = The Sound of Music
# budget = $8,200,000 (estimated)
# gross_us = $159,287,539
# opening_week_rev = $413,497
# opening_week_date = Sep 9, 2018
# gross_world = $159,475,084
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 8200000
# gross_us = 159287539
# opening_week_rev = 413497
# opening_week_date = 2018-09-09 00:00:00
# gross_world = 159475084
# Movie Title = Into the Wild
# budget = $15,000,000 (estimated)
# gross_us = $18,354,356
# opening_week_rev = $212,440
# opening_week_date = Sep 23, 2007
# gross_world = $56,676,733
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 15000000
# gross_us = 18354356
# opening_week_rev = 212440
# opening_week_date = 2007-09-23 00:00:00
# gross_world = 56676733
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 148
# color = Color
# sound = DTSDolby DigitalSDDS
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = To Be or Not to Be
# Movie Title = The Battle of Algiers
# budget = $800,000 (estimated)
# gross_us = $879,794
# opening_week_rev = $64,870
# opening_week_date = Jan 11, 2004
# gross_world = $962,002
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 800000
# gross_us = 879794
# opening_week_rev = 64870
# opening_week_date = 2004-01-11 00:00:00
# gross_world = 962002
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 121
# color = Black and White
# sound = Mono
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = The Grapes of Wrath
# Movie Title = Groundhog Day
# budget = $14,600,000 (estimated)
# gross_us = $71,107,962
# opening_week_rev = $12,517,672
# opening_week_date = Feb 14, 1993
# gross_world = $71,108,778
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 14600000
# gross_us = 71107962
# opening_week_rev = 12517672
# opening_week_date = 1993-02-14 00:00:00
# gross_world = 71108778
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 101
# color = Color
# sound = Dolby StereoDolby DigitalDolby Atmos
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = Amores perros
# budget = $2,000,000 (estimated)
# gross_us = $5,408,467
# opening_week_rev = $61,047
# opening_week_date = Apr 1, 2001
# gross_world = $20,908,467
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 2000000
# gross_us = 5408467
# opening_week_rev = 61047
# opening_week_date = 2001-04-01 00:00:00
# gross_world = 20908467
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 154
# color = Color
# sound = Dolby Digital
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = The Iron Giant
# budget = $70,000,000 (estimated)
# gross_us = $23,315,035
# opening_week_rev = $5,732,614
# opening_week_date = Aug 8, 1999
# gross_world = $23,336,504
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 70000000
# gross_us = 23315035
# opening_week_rev = 5732614
# opening_week_date = 1999-08-08 00:00:00
# gross_world = 23336504
# Movie Title = Rebecca
# Movie Title = Cool Hand Luke
# Movie Title = The Help
# budget = $25,000,000 (estimated)
# gross_us = $169,708,112
# opening_week_rev = $26,044,590
# opening_week_date = Aug 14, 2011
# gross_world = $216,639,112
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 25000000
# gross_us = 169708112
# opening_week_rev = 26044590
# opening_week_date = 2011-08-14 00:00:00
# gross_world = 216639112
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 146
# color = Color
# sound = Dolby DigitalSDDSDatasat
# aspect_ratio = 1.85 : 1
# =====================================
# Movie Title = It Happened One Night
# Movie Title = Drishyam
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 163
# color = Color
# sound = Dolby Digital
# aspect_ratio = 2.35 : 1
# =====================================
# Movie Title = Dances with Wolves
# budget = $22,000,000 (estimated)
# gross_us = $184,208,848
# opening_week_rev = $598,257
# opening_week_date = Nov 11, 1990
# gross_world = $424,208,848
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 22000000
# gross_us = 184208848
# opening_week_rev = 598257
# opening_week_date = 1990-11-11 00:00:00
# gross_world = 424208848
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 181
# color = Color
# sound = Dolby SR
# aspect_ratio = 2.39 : 1
# =====================================
# Movie Title = Aladdin
# budget = $28,000,000 (estimated)
# gross_us = $217,350,219
# opening_week_rev = $196,664
# opening_week_date = Nov 15, 1992
# gross_world = $504,050,219
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 28000000
# gross_us = 217350219
# opening_week_rev = 196664
# opening_week_date = 1992-11-15 00:00:00
# gross_world = 504050219
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 90
# color = Color
# sound = Dolby Stereo
# aspect_ratio = 1.78 : 11.85 : 1
# =====================================
# Movie Title = Gangs of Wasseypur
# =====================================
# Technical Specification
# -----------------------------------
# runtime = 321
# color = Color
# sound = Dolby Digital EXDatasat
# aspect_ratio = 2.35 : 1
# =====================================

# %%
links = browser.find_elements(By.XPATH, '//div[@class="sc-b189961a-0 hBZnfJ"]')
count = 0
print("-----------------------------------")
print("-----------------------------------")
print("SECONDARY DATA")
print("panjang ", len(links))
movie_titles = browser.find_elements(By.XPATH, '//h3[@class="ipc-title__text"]')
print("panjang judul:", len(movie_titles)-1)
        
        # break
        
for link in links:
    title = re.sub(r"\d+. ","", movie_titles[count].text)
    print("judul ke-" + str(count+1) + ": " + title)
    count += 1
    budget_num = 0
    gross_us_num = 0
    open_week_rev_num = 0
    open_week_date_std = "1900-01-01 00:00:00"
    gross_world_num = 0
    # # link = row.find_element(By.XPATH, '//a[@href="'+url+'"]')
    # # link = row.find_element(By.XPATH, '//a[@class="ipc-title-link-wrapper"]').get_attribute('href')
    # link = row.find_element(By.XPATH, '//div[@class="ipc-title ipc-title--base ipc-title--title ipc-title-link-no-icon ipc-title--on-textPrimary sc-b189961a-9 iALATN dli-title"]/a').get_attribute('href')
   # # link = row.fine_element(By.CSS_SELECTOR, "a")
    print("----------------------")
    print(count, link.find_element(By.CSS_SELECTOR, "a").get_attribute('href'), "\n")
    browser2.get(link.find_element(By.CSS_SELECTOR, "a").get_attribute('href'))

            # BOX OFFICE DATA ON THE 2ND URL
    det_page = browser2.page_source        
    container_rows = BeautifulSoup(det_page, "html.parser")        
    box_office_elements = container_rows.find("div",{"data-testid":"title-boxoffice-section"})
    if box_office_elements is not None:
        det_movie = box_office_elements.find_all("span",{"class":"ipc-metadata-list-item__list-content-item"})

        if len(det_movie) > 4:

            budget = det_movie[0].text
            gross_us = det_movie[1].text
            open_week_rev = det_movie[2].text
            open_week_date = det_movie[3].text            
            gross_world = det_movie[4].text

            print("budget = " + budget)
            print("gross_us = " + gross_us)
            print("opening_week_rev = " + open_week_rev)
            print("opening_week_date = " + open_week_date)
            print("gross_world = " + gross_world)

                # print(det_page)
                # print("\n")
            print("=====================================")
            budget_num = int(re.sub("[A-Z£€₹$,()a-z]","",budget))
            gross_us_num = int(re.sub("[A-Z£€₹$,()a-z]","",gross_us))
            open_week_rev_num = int(re.sub("[A-Z£€₹$,()a-z]","",open_week_rev))
            open_week_date_std = datetime.strptime(open_week_date, "%b %d, %Y")
            gross_world_num = int(re.sub("[A-Z£€₹$,()a-z]","",gross_world))

            print("Data has been formatted to standard")
            print("-----------------------------------")
            print("budget =", budget_num)
            print("gross_us =" , gross_us_num)
            print("opening_week_rev =" , open_week_rev_num)
            print("opening_week_date =", open_week_date_std)
            print("gross_world =", gross_world_num)
# Out:
# -----------------------------------
# -----------------------------------
# SECONDARY DATA
# panjang  0
# panjang judul: 263

# %%
my_url = "http://www.imdb.com/search/title?sort=num_votes,desc&start=1&title_type=feature&year=2024,2024"

# %%
filename = "imdb_primary_data.csv"
filename2 = "imdb_secondary_data.csv"
browser = webdriver.Chrome(options=chrome_options, service = service)
browser2 = webdriver.Chrome(options=chrome_options, service = service)

# %%
print(os.path.exists(filename))
print(os.path.isfile(filename))
# Out:
# True
# True

# %%
if os.path.isfile(filename) or os.path.getsize(filename) > 0:
    print("File exists and is not empty")
    f = open(filename, "w")
    fheaders = "Name,Year,Durasi(Menit),Rating\n"
    f2 = open(filename2, "w")
    f2headers = "Name,Budget,Gross_US,Opening_Week,Open_Week_Date,Gross_World\n"
    
    f.write(fheaders)
    f2.write(f2headers)

    try:
        browser.get(my_url)
        # ACTION 1
        first_page = BeautifulSoup(browser.page_source ,'html.parser')
        movies = first_page.find_all("div", {"class":"sc-b189961a-0 hBZnfJ"})

        count2 = 0
        print("Primary Data")
        print("-----------------------------------")
        for movie in movies:
            count2 += 1
            menit = 0
            rating = "Not Rated"
            name = re.sub(r"\d+. ","", movie.find("h3", {"class": "ipc-title__text"}).text)
            detil_line = movie.findAll("span", {"class": "sc-b189961a-8 kLaxqf dli-title-metadata-item"})
            if len(detil_line) > 2:        
                year_movie = detil_line[0].text
                durasi = detil_line[1].text
                durasi = durasi.split(" ")
                if len(durasi) > 1:
                    menit = int(durasi[0].replace("h","")) * 60 + int(durasi[1].replace("m",""))   
                else:
                    menit = int(durasi[0].replace("h","")) * 60 
                # durasi_menit = 
                rating = detil_line[2].text
            elif len(detil_line) > 1:
                year_movie = detil_line[0].text
                durasi = detil_line[1].text
                durasi = durasi.split(" ")
                if len(durasi) > 1:
                    menit = int(durasi[0].replace("h","")) * 60 + int(durasi[1].replace("m",""))   
                else:
                    menit = int(durasi[0].replace("h","")) * 60 
            else:
                year_movie = detil_line[0].text        
        
            print("-----------------------------------")
            print(name + "," + year_movie + "," + str(menit) + "," + rating)  
            f.write(name + "," + year_movie + "," + str(menit) + "," + rating + "\n")

        # ACTION 2
        links = browser.find_elements(By.XPATH, '//div[@class="sc-b189961a-0 hBZnfJ"]')
        count = 0
        print("-----------------------------------")
        print("-----------------------------------")
        print("SECONDARY DATA")
        print("panjang ", len(links))
        movie_titles = browser.find_elements(By.XPATH, '//h3[@class="ipc-title__text"]')
        # print("panjang judul:", len(movie_titles)-1)
        
        # break
        
        for link in links:
            title = re.sub(r"\d+. ","", movie_titles[count].text)
            print("judul ke-" + str(count+1) + ": " + title)
            count += 1
            budget_num = 0
            gross_us_num = 0
            open_week_rev_num = 0
            open_week_date_std = "1900-01-01 00:00:00"
            gross_world_num = 0
            # # link = row.find_element(By.XPATH, '//a[@href="'+url+'"]')
            # # link = row.find_element(By.XPATH, '//a[@class="ipc-title-link-wrapper"]').get_attribute('href')
            # link = row.find_element(By.XPATH, '//div[@class="ipc-title ipc-title--base ipc-title--title ipc-title-link-no-icon ipc-title--on-textPrimary sc-b189961a-9 iALATN dli-title"]/a').get_attribute('href')
            # # link = row.fine_element(By.CSS_SELECTOR, "a")
            print("----------------------")
            print(count, link.find_element(By.CSS_SELECTOR, "a").get_attribute('href'), "\n")
            browser2.get(link.find_element(By.CSS_SELECTOR, "a").get_attribute('href'))

            # BOX OFFICE DATA ON THE 2ND URL
            det_page = browser2.page_source        
            container_rows = BeautifulSoup(det_page, "html.parser")        
            box_office_elements = container_rows.find("div",{"data-testid":"title-boxoffice-section"})
            if box_office_elements is not None:
                det_movie = box_office_elements.find_all("span",{"class":"ipc-metadata-list-item__list-content-item"})
                if len(det_movie) > 4:

                    budget = det_movie[0].text
                    gross_us = det_movie[1].text
                    open_week_rev = det_movie[2].text
                    open_week_date = det_movie[3].text            
                    gross_world = det_movie[4].text

                    print("budget = " + budget)
                    print("gross_us = " + gross_us)
                    print("opening_week_rev = " + open_week_rev)
                    print("opening_week_date = " + open_week_date)
                    print("gross_world = " + gross_world)

                    # print(det_page)
                    # print("\n")
                    print("=====================================")
                    budget_num = int(re.sub("[A-Z£€₹$,()a-z]","",budget))
                    gross_us_num = int(re.sub("[A-Z£€₹$,()a-z]","",gross_us))
                    open_week_rev_num = int(re.sub("[A-Z£€₹$,()a-z]","",open_week_rev))
                    open_week_date_std = datetime.strptime(open_week_date, "%b %d, %Y")
                    gross_world_num = int(re.sub("[A-Z£€₹$,()a-z]","",gross_world))

                    print("Data has been formatted to standard")
                    print("-----------------------------------")
                    print("budget =", budget_num)
                    print("gross_us =" , gross_us_num)
                    print("opening_week_rev =" , open_week_rev_num)
                    print("opening_week_date =", open_week_date_std)
                    print("gross_world =", gross_world_num)

            f2.write(str(title) + "," + str(budget_num) + "," + str(gross_us_num) + "," + str(open_week_rev_num) + "," + str(open_week_date_std) + "," + str(gross_world_num) + "\n")
    except Exception as E:
        print(E)
        f.close()
        f2.close()
# Out:
# File exists and is not empty
# Primary Data
# -----------------------------------
# -----------------------------------
# -----------------------------------
# SECONDARY DATA
# panjang  0
